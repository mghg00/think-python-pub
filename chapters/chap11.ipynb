# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');

import thinkpython

# %% [markdown]
# # Tuples
#
# This chapter introduces one more built-in type, the tuple, and then shows how lists, dictionaries, and tuples work together.
# It also presents tuple assignment and a useful feature for functions with variable-length argument lists: the packing and unpacking operators.
#
# In the exercises, we'll use tuples, along with lists and dictionaries, to solve more word puzzles and implement efficient algorithms.
#
# One note: There are two ways to pronounce "tuple".
# Some people say "tuh-ple", which rhymes with "supple".
# But in the context of programming, most people say "too-ple", which rhymes with "quadruple".

# %% [markdown]
# ## Tuples are like lists
#
# A tuple is a sequence of values. The values can be any type, and they are indexed by integers, so tuples are a lot like lists.
# The important difference is that tuples are immutable.
#
# To create a tuple, you can write a comma-separated list of values.

# %%
t = 'l', 'u', 'p', 'i', 'n'
type(t)
# Out:
# tuple

# %% [markdown]
# Although it is not necessary, it is common to enclose tuples in parentheses.

# %%
t = ('l', 'u', 'p', 'i', 'n')
type(t)
# Out:
# tuple

# %% [markdown]
# To create a tuple with a single element, you have to include a final comma.

# %%
t1 = 'p',
type(t1)
# Out:
# tuple

# %% [markdown]
# A single value in parentheses is not a tuple.

# %%
t2 = ('p')
type(t2)
# Out:
# str

# %% [markdown]
# Another way to create a tuple is the built-in function `tuple`. With no
# argument, it creates an empty tuple.

# %%
t = tuple()
t
# Out:
# ()

# %% [markdown]
# If the argument is a sequence (string, list or tuple), the result is a
# tuple with the elements of the sequence.

# %%
t = tuple('lupin')
t
# Out:
# ('l', 'u', 'p', 'i', 'n')

# %% [markdown]
# Because `tuple` is the name of a built-in function, you should avoid using it as a variable name.
#
# Most list operators also work with tuples.
# For example, the bracket operator indexes an element.

# %%
t[0]
# Out:
# 'l'

# %% [markdown]
# And the slice operator selects a range of elements.

# %%
t[1:3]
# Out:
# ('u', 'p')

# %% [markdown]
# The `+` operator concatenates tuples.

# %%
tuple('lup') + ('i', 'n')
# Out:
# ('l', 'u', 'p', 'i', 'n')

# %% [markdown]
# And the `*` operator duplicates a tuple a given number of times.

# %%
tuple('spam') * 2
# Out:
# ('s', 'p', 'a', 'm', 's', 'p', 'a', 'm')

# %% [markdown]
# The `sorted` function works with tuples -- but the result is a list, not a tuple.

# %%
sorted(t)
# Out:
# ['i', 'l', 'n', 'p', 'u']

# %% [markdown]
# The `reversed` function also works with tuples.

# %%
reversed(t)

# %% [markdown]
# The result is a `reversed` object, which we can convert to a list or tuple.

# %%
tuple(reversed(t))
# Out:
# ('n', 'i', 'p', 'u', 'l')

# %% [markdown]
# Based on the examples so far, it might seem like tuples are the same as lists.

# %% [markdown]
# ## But tuples are immutable
#
# If you try to modify a tuple with the bracket operator, you get a `TypeError`.

# %%
# %%expect TypeError
# t[0] = 'L'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-243455819.py in <cell line: 0>()
# ----> 1 t[0] = 'L'
#         global t = ('l', 'u', 'p', 'i', 'n')
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# And tuples don't have any of the methods that modify lists, like `append` and `remove`.

# %%
# %%expect AttributeError
#
# t.remove('l')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1747219066.py in <cell line: 0>()
# ----> 1 t.remove('l')
#         global t.remove = undefined
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# Recall that an "attribute" is a variable or method associated with an object -- this error message means that tuples don't have a method named `remove`.
#
# Because tuples are immutable, they are hashable, which means they can be used as keys in a dictionary.
# For example, the following dictionary contains two tuples as keys that map to integers.

# %%
d = {}
d[1, 2] = 3
d[3, 4] = 7

# %% [markdown]
# We can look up a tuple in a dictionary like this:

# %%
d[1, 2]
# Out:
# 3

# %% [markdown]
# Or if we have a variable that refers to a tuple, we can use it as a key.

# %%
t = (3, 4)
d[t]
# Out:
# 7

# %% [markdown]
# Tuples can also appear as values in a dictionary.

# %%
t = tuple('abc')
d = {'key': t}
d
# Out:
# {'key': ('a', 'b', 'c')}

# %% [markdown]
# ## Tuple assignment
#
# You can put a tuple of variables on the left side of an assignment, and a tuple of values on the right.

# %%
a, b = 1, 2

# %% [markdown]
# The values are assigned to the variables from left to right -- in this example, `a` gets the value `1` and `b` gets the value `2`.
# We can display the results like this:

# %%
a, b
# Out:
# (1, 2)

# %% [markdown]
# More generally, if the left side of an assignment is a tuple, the right side can be any kind of sequence -- string, list or tuple.
# For example, to split an email address into a user name and a domain, you could write:

# %%
email = 'monty@python.org'
username, domain = email.split('@')

# %% [markdown]
# The return value from `split` is a list with two elements -- the first element is assigned to `username`, the second to `domain`.

# %%
username, domain
# Out:
# ('monty', 'python.org')

# %% [markdown]
# The number of variables on the left and the number of values on the
# right have to be the same -- otherwise you get a `ValueError`.

# %%
# %%expect ValueError
# a, b = 1, 2, 3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-134867213.py in <cell line: 0>()
# ----> 1 a, b = 1, 2, 3
#         global a = 1
#         global b = 2
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# Tuple assignment is useful if you want to swap the values of two variables.
# With conventional assignments, you have to use a temporary variable, like this:

# %%
temp = a
a = b
b = temp

# %% [markdown]
# That works, but with tuple assignment we can do the same thing without a temporary variable.

# %%
a, b = b, a

# %% [markdown]
# This works because all of the expressions on the right side are evaluated before any of the assignments.
#
# We can also use tuple assignment in a `for` statement.
# For example, to loop through the items in a dictionary, we can use the `items` method.

# %%
d = {'one': 1, 'two': 2}

for item in d.items():
    key, value = item
    print(key, '->', value)
# Out:
# one -> 1
# two -> 2

# %% [markdown]
# Each time through the loop, `item` is assigned a tuple that contains a key and the corresponding value.
#
# We can write this loop more concisely, like this:

# %%
for key, value in d.items():
    print(key, '->', value)
# Out:
# one -> 1
# two -> 2

# %% [markdown]
# Each time through the loop, a key and the corresponding value are assigned directly to `key` and `value`.

# %% [markdown]
# ## Tuples as return values
#
# Strictly speaking, a function can only return one value, but if the
# value is a tuple, the effect is the same as returning multiple values.
# For example, if you want to divide two integers and compute the quotient
# and remainder, it is inefficient to compute `x//y` and then `x%y`. It is
# better to compute them both at the same time.
#
# The built-in function `divmod` takes two arguments and returns a tuple
# of two values, the quotient and remainder.

# %%
divmod(7, 3)
# Out:
# (2, 1)

# %% [markdown]
# We can use tuple assignment to store the elements of the tuple in two variables.

# %%
quotient, remainder = divmod(7, 3)
quotient
# Out:
# 2

# %%
remainder
# Out:
# 1

# %% [markdown]
# Here is an example of a function that returns a tuple.

# %%
def min_max(t):
    return min(t), max(t)

# %% [markdown]
# `max` and `min` are built-in functions that find the largest and smallest elements of a sequence.
# `min_max` computes both and returns a tuple of two values.

# %%
min_max([2, 4, 1, 3])
# Out:
# (1, 4)

# %% [markdown]
# We can assign the results to variables like this:

# %%
low, high = min_max([2, 4, 1, 3])
low, high
# Out:
# (1, 4)

# %% [markdown]
# ## Argument packing
#
# Functions can take a variable number of arguments.
# A parameter name that begins with the `*` operator **packs** arguments into a tuple.
# For example, the following function takes any number of arguments and computes their arithmetic mean -- that is, their sum divided by the number of arguments.

# %%
def mean(*args):
    return sum(args) / len(args)

# %% [markdown]
# The parameter can have any name you like, but `args` is conventional.
# We can call the function like this:

# %%
mean(1, 2, 3)
# Out:
# 2.0

# %% [markdown]
# If you have a sequence of values and you want to pass them to a function as multiple arguments, you can use the `*` operator to **unpack** the tuple.
# For example, `divmod` takes exactly two arguments -- if you pass a tuple as a parameter, you get an error.

# %%
# %%expect TypeError
# t = (7, 3)
# divmod(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2828392833.py in <cell line: 0>()
#       1 t = (7, 3)
# ----> 2 divmod(t)
#         global divmod = undefined
#         global t = (7, 3)
#
# TypeError: divmod expected 2 arguments, got 1

# %% [markdown]
# Even though the tuple contains two elements, it counts as a single argument.
# But if you unpack the tuple, it is treated as two arguments.

# %%
divmod(*t)
# Out:
# (2, 1)

# %% [markdown]
# Packing and unpacking can be useful if you want to adapt the behavior of an existing function.
# For example, this function takes any number of arguments, removes the lowest and highest, and computes the mean of the rest.

# %%
def trimmed_mean(*args):
    low, high = min_max(args)
    trimmed = list(args)
    trimmed.remove(low)
    trimmed.remove(high)
    return mean(*trimmed)

# %% [markdown]
# First it uses `min_max` to find the lowest and highest elements.
# Then it converts `args` to a list so it can use the `remove` method.
# Finally it unpacks the list so the elements are passed to `mean` as separate arguments, rather than as a single list.
#
# Here's an example that shows the effect.

# %%
mean(1, 2, 3, 10)
# Out:
# 4.0

# %%
trimmed_mean(1, 2, 3, 10)
# Out:
# 2.5

# %% [markdown]
# This kind of "trimmed" mean is used in some sports with subjective judging -- like diving and gymnastics -- to reduce the effect of a judge whose score deviates from the others.

# %% [markdown]
# ## Zip
#
# Tuples are useful for looping through the elements of two sequences and performing operations on corresponding elements.
# For example, suppose two teams play a series of seven games, and we record their scores in two lists, one for each team.

# %%
scores1 = [1, 2, 4, 5, 1, 5, 2]
scores2 = [5, 5, 2, 2, 5, 2, 3]

# %% [markdown]
# Let's see how many games each team won.
# We'll use `zip`, which is a built-in function that takes two or more sequences and returns a **zip object**, so-called because it pairs up the elements of the sequences like the teeth of a zipper.

# %%
zip(scores1, scores2)

# %% [markdown]
# We can use the zip object to loop through the values in the sequences pairwise.

# %%
for pair in zip(scores1, scores2):
     print(pair)
# Out:
# (1, 5)
# (2, 5)
# (4, 2)
# (5, 2)
# (1, 5)
# (5, 2)
# (2, 3)

# %% [markdown]
# Each time through the loop, `pair` gets assigned a tuple of scores.
# So we can assign the scores to variables, and count the victories for the first team, like this:

# %%
wins = 0
for team1, team2 in zip(scores1, scores2):
    if team1 > team2:
        wins += 1

wins
# Out:
# 3

# %% [markdown]
# Sadly, the first team won only three games and lost the series.
#
# If you have two lists and you want a list of pairs, you can use `zip` and `list`.

# %%
t = list(zip(scores1, scores2))
t
# Out:
# [(1, 5), (2, 5), (4, 2), (5, 2), (1, 5), (5, 2), (2, 3)]

# %% [markdown]
# The result is a list of tuples, so we can get the result of the last game like this:

# %%
t[-1]
# Out:
# (2, 3)

# %% [markdown]
# If you have a list of keys and a list of values, you can use `zip` and `dict` to make a dictionary.
# For example, here's how we can make a dictionary that maps from each letter to its position in the alphabet.

# %%
letters = 'abcdefghijklmnopqrstuvwxyz'
numbers = range(len(letters))
letter_map = dict(zip(letters, numbers))

# %% [markdown]
# Now we can look up a letter and get its index in the alphabet.

# %%
letter_map['a'], letter_map['z']
# Out:
# (0, 25)

# %% [markdown]
# In this mapping, the index of `'a'` is `0` and the index of `'z'` is `25`.
#
# If you need to loop through the elements of a sequence and their indices, you can use the built-in function `enumerate`.

# %%
enumerate('abc')

# %% [markdown]
# The result is an **enumerate object** that loops through a sequence of pairs, where each pair contains an index (starting from 0) and an element from the given sequence.

# %%
for index, element in enumerate('abc'):
    print(index, element)
# Out:
# 0 a
# 1 b
# 2 c

# %% [markdown]
# ## Comparing and Sorting
#
# The relational operators work with tuples and other sequences.
# For example, if you use the `<` operator with tuples, it starts by comparing the first element from each sequence.
# If they are equal, it goes on to the next pair of elements, and so on, until it finds a pair that differ.

# %%
(0, 1, 2) < (0, 3, 4)
# Out:
# True

# %% [markdown]
# Subsequent elements are not considered -- even if they are really big.

# %%
(0, 1, 2000000) < (0, 3, 4)
# Out:
# True

# %% [markdown]
# This way of comparing tuples is useful for sorting a list of tuples, or finding the minimum or maximum.
# As an example, let's find the most common letter in a word.
# In the previous chapter, we wrote `value_counts`, which takes a string and returns a dictionary that maps from each letter to the number of times it appears.

# %%
def value_counts(string):
    counter = {}
    for letter in string:
        if letter not in counter:
            counter[letter] = 1
        else:
            counter[letter] += 1
    return counter

# %% [markdown]
# Here is the result for the string `'banana'`.

# %%
counter = value_counts('banana')
counter
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %% [markdown]
# With only three items, we can easily see that the most frequent letter is `'a'`, which appears three times.
# But if there were more items, it would be useful to sort them automatically.
#
# We can get the items from `counter` like this.

# %%
items = counter.items()
items
# Out:
# dict_items([('b', 1), ('a', 3), ('n', 2)])

# %% [markdown]
# The result is a `dict_items` object that behaves like a list of tuples, so we can sort it like this.

# %%
sorted(items)
# Out:
# [('a', 3), ('b', 1), ('n', 2)]

# %% [markdown]
# The default behavior is to use the first element from each tuple to sort the list, and use the second element to break ties.
#
# However, to find the items with the highest counts, we want to use the second element to sort the list.
# We can do that by writing a function that takes a tuple and returns the second element.

# %%
def second_element(t):
    return t[1]

# %% [markdown]
# Then we can pass that function to `sorted` as an optional argument called `key`, which indicates that this function should be used to compute the **sort key** for each item.

# %%
sorted_items = sorted(items, key=second_element)
sorted_items
# Out:
# [('b', 1), ('n', 2), ('a', 3)]

# %% [markdown]
# The sort key determines the order of the items in the list.
# The letter with the lowest count appears first, and the letter with the highest count appears last.
# So we can find the most common letter like this.

# %%
sorted_items[-1]
# Out:
# ('a', 3)

# %% [markdown]
# If we only want the maximum, we don't have to sort the list.
# We can use `max`, which also takes `key` as an optional argument.

# %%
max(items, key=second_element)
# Out:
# ('a', 3)

# %% [markdown]
# To find the letter with the lowest count, we could use `min` the same way.

# %% [markdown]
# ## Inverting a dictionary
#
# Suppose you want to invert a dictionary so you can look up a value and get the corresponding key.
# For example, if you have a word counter that maps from each word to the number of times it appears, you could make a dictionary that maps from integers to the words that appear that number of times.
#
# But there's a problem -- the keys in a dictionary have to be unique, but the values don't. For example, in a word counter, there could be many words with the same count.
#
# So one way to invert a dictionary is to create a new dictionary where the values are lists of keys from the original.
# As an example, let's count the letters in `parrot`.

# %%
d =  value_counts('parrot')
d
# Out:
# {'p': 1, 'a': 1, 'r': 2, 'o': 1, 't': 1}

# %% [markdown]
# If we invert this dictionary, the result should be `{1: ['p', 'a', 'o', 't'], 2: ['r']}`, which indicates that the letters that appear once are `'p'`, `'a'`, `'o'`, and `'t'`, and the letter than appears twice is `'r'`.
#
# The following function takes a dictionary and returns its inverse as a new dictionary.

# %%
def invert_dict(d):
    new = {}
    for key, value in d.items():
        if value not in new:
            new[value] = [key]
        else:
            new[value].append(key)
    return new

# %% [markdown]
# The `for` statement loops through the keys and values in `d`.
# If the value is not already in the new dictionary, it is added and associated with a list that contains a single element.
# Otherwise it is appended to the existing list.
#
# We can test it like this:

# %%
invert_dict(d)
# Out:
# {1: ['p', 'a', 'o', 't'], 2: ['r']}

# %% [markdown]
# And we get the result we expected.
#
# This is the first example we've seen where the values in the dictionary are lists.
# We will see more!

# %% [markdown]
# ## Debugging
#
# Lists, dictionaries and tuples are **data structures**.
# In this chapter we are starting to see compound data structures, like lists of tuples, or dictionaries that contain tuples as keys and lists as values.
# Compound data structures are useful, but they are prone to errors caused when a data structure has the wrong type, size, or structure.
# For example, if a function expects a list of integers and you give it a plain old integer
# (not in a list), it probably won't work.
#
# To help debug these kinds of errors, I wrote a module called `structshape` that provides a function, also called `structshape`, that takes any kind of data structure as an argument and returns a string that summarizes its structure.
# You can download it from
# <https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/structshape.py>.

# %%
download('https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/structshape.py');

# %% [markdown]
# We can import it like this.

# %%
from structshape import structshape

# %% [markdown]
# Here's an example with a simple list.

# %%
t = [1, 2, 3]
structshape(t)
# Out:
# 'list of 3 int'

# %% [markdown]
# Here's a list of lists.

# %%
t2 = [[1,2], [3,4], [5,6]]
structshape(t2)
# Out:
# 'list of 3 list of 2 int'

# %% [markdown]
# If the elements of the list are not the same type, `structshape` groups
# them by type.

# %%
t3 = [1, 2, 3, 4.0, '5', '6', [7], [8], 9]
structshape(t3)
# Out:
# 'list of (3 int, float, 2 str, 2 list of int, int)'

# %% [markdown]
# Here's a list of tuples.

# %%
s = 'abc'
lt = list(zip(t, s))
structshape(lt)
# Out:
# 'list of 3 tuple of (int, str)'

# %% [markdown]
# And here's a dictionary with three items that map integers to strings.

# %%
d = dict(lt)
structshape(d)
# Out:
# 'dict of 3 int->str'

# %% [markdown]
# If you are having trouble keeping track of your data structures,
# `structshape` can help.

# %% [markdown]
# ## Glossary
#
# **pack:**
# Collect multiple arguments into a tuple.
#
# **unpack:**
# Treat a tuple (or other sequence) as multiple arguments.
#
# **zip object:**
# The result of calling the built-in function `zip`, can be used to loop through a sequence of tuples.
#
# **enumerate object:**
# The result of calling the built-in function `enumerate`, can be used to loop through a sequence of tuples.
#
# **sort key:**
# A value, or function that computes a value, used to sort the elements of a collection.
#
# **data structure:**
# A collection of values, organized to perform certain operations efficiently.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# ### Ask a virtual assistant
#
# The exercises in this chapter might be more difficult than exercises in previous chapters, so I encourage you to get help from a virtual assistant.
# When you pose more difficult questions, you might find that the answers are not correct on the first attempt, so this is a chance to practice crafting good prompts and following up with good refinements.
#
# One strategy you might consider is to break a big problems into pieces that can be solved with simple functions.
# Ask the virtual assistant to write the functions and test them.
# Then, once they are working, ask for a solution to the original problem.
#
# For some of the exercises below, I make suggestions about which data structures and algorithms to use.
# You might find these suggestions useful when you work on the problems, but they are also good prompts to pass along to a virtual assistant.

# %% [markdown]
# ### Exercise
#
# In this chapter I said that tuples can be used as keys in dictionaries because they are hashable, and they are hashable because they are immutable.
# But that is not always true.
#
# If a tuple contains a mutable value, like a list or a dictionary, the tuple is no longer hashable because it contains elements that are not hashable. As an example, here's a tuple that contains two lists of integers.

# %%
list0 = [1, 2, 3]
list1 = [4, 5]

t = (list0, list1)
t
# Out:
# ([1, 2, 3], [4, 5])

# %% [markdown]
# Write a line of code that appends the value `6` to the end of the second list in `t`. If you display `t`, the result should be `([1, 2, 3], [4, 5, 6])`.

# %%
# Solution goes here
t[1].append(6)
t
# Out:
# ([1, 2, 3], [4, 5, 6])

# %% [markdown]
# Try to create a dictionary that maps from `t` to a string, and confirm that you get a `TypeError`.

# %%
# Solution goes here
d = {}
d[t] = 'some_string'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1515298460.py in <cell line: 0>()
#       1 # Solution goes here
#       2 d = {}
# ----> 3 d[t] = 'some_string'
#         global d = {}
#         global t = ([1, 2, 3], [4, 5, 6])
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# For more on this topic, ask a virtual assistant, "Are Python tuples always hashable?"

# %% [markdown]
# ### Exercise
#
# In this chapter we made a dictionary that maps from each letter to its index in the alphabet.

# %%
letters = 'abcdefghijklmnopqrstuvwxyz'
numbers = range(len(letters))
letter_map = dict(zip(letters, numbers))

# %% [markdown]
# For example, the index of `'a'` is `0`.

# %%
letter_map['a']
# Out:
# 0

# %% [markdown]
# To go in the other direction, we can use list indexing.
# For example, the letter at index `1` is `'b'`.

# %%
letters[1]
# Out:
# 'b'

# %% [markdown]
# We can use `letter_map` and `letters` to encode and decode words using a Caesar cipher.
#
# A Caesar cipher is a weak form of encryption that involves shifting each letter
# by a fixed number of places in the alphabet, wrapping around to the beginning if necessary. For example, `'a'` shifted by 2 is `'c'` and `'z'` shifted by 1 is `'a'`.
#
# Write a function called `shift_word` that takes as parameters a string and an integer, and returns a new string that contains the letters from the string shifted by the given number of places.
#
# To test your function, confirm that "cheer" shifted by 7 is "jolly" and "melon" shifted by 16 is "cubed".
#
# Hints: Use the modulus operator to wrap around from `'z'` back to `'a'`.
# Loop through the letters of the word, shift each one, and append the result to a list of letters.
# Then use `join` to concatenate the letters into a string.

# %% [markdown]
# You can use this outline to get started.

# %%
def shift_word(word, n):
    """Shift the letters of `word` by `n` places.
    t
    >>> shift_word('cheer', 7)
    'jolly'
    >>> shift_word('melon', 16)
    'cubed'
    """
    return None

# %%
# Solution goes here
def shift_word(word, n):
    """Shift the letters of `word` by `n` places.

    >>> shift_word('cheer', 7)
    'jolly'
    >>> shift_word('melon', 16)
    'cubed'
    """
    letters = 'abcdefghijklmnopqrstuvwxyz'
    numbers = range(len(letters))
    letter_map = dict(zip(letters, numbers))
    shifted_word = ''
    for letter in word:
        shifted_index = (letter_map[letter] + n) % len(letters)
        shifted_letter = letters[shifted_index]
        shifted_word += shifted_letter
    return shifted_word

# %%
shift_word('cheer', 7)
# Out:
# 'jolly'

# %%
shift_word('melon', 16)
# Out:
# 'cubed'

# %% [markdown]
# You can use `doctest` to test your function.

# %%
from doctest import run_docstring_examples

def run_doctests(func):
    run_docstring_examples(func, globals(), name=func.__name__)

run_doctests(shift_word)

# %% [markdown]
# ### Exercise
#
# Write a function called `most_frequent_letters` that takes a string and prints the letters in decreasing order of frequency.
#
# To get the items in decreasing order, you can use `reversed` along with `sorted` or you can pass `reverse=True` as a keyword parameter to `sorted`.

# %% [markdown]
# You can use this outline of the function to get started.

# %%
def most_frequent_letters(string):
    return None

# %%
# Solution goes here
def most_frequent_letters(string):
    counter = value_counts(string.upper())
    items = counter.items()
    sorted_items = sorted(items, key=second_element, reverse=True)
    for item in sorted_items:
        print(item[0])

# %% [markdown]
# And this example to test your function.

# %%
most_frequent_letters('brontosaurus')
# Out:
# R
# O
# S
# U
# B
# N
# T
# A

# %% [markdown]
# Once your function is working, you can use the following code to print the most common letters in *Dracula*, which we can download from Project Gutenberg.

# %%
download('https://www.gutenberg.org/cache/epub/345/pg345.txt');

# %%
string = open('pg345.txt').read()
most_frequent_letters(string)
# Out:
#
# E
# T
# A
# O
# N
# H
# I
# S
# R
# D
# L
# U
# W
# M
#
#
# F
# C
# G
# Y
# ,
# P
# B
# .
# K
# V
# -
# ;
# ’
# “
# ”
# _
# J
# X
# !
# *
# :
# Q
# ?
# Z
# 1
# 2
# ‘
# 3
# 0
# ™
# (
# )
# 5
# 4
# 7
# 9
# 8
# 6
# &
# È
# Æ
# Ö
# /
# •
# [
# ]
# —
# Ë
# £
# {
# }
# É
# Â
# Ï
# $
# ﻿
# #
# Á
# Ô
# À
# %

# %% [markdown]
# According to Zim's "Codes and Secret Writing", the sequence of letters in decreasing order of frequency in English starts with "ETAONRISH".
# How does this sequence compare with the results from *Dracula*?

# %% [markdown]
# ### Exercise
#
# In a previous exercise, we tested whether two strings are anagrams by sorting the letters in both words and checking whether the sorted letters are the same.
# Now let's make the problem a little more challenging.
#
# We'll write a program that takes a list of words and prints all the sets of words that are anagrams.
# Here is an example of what the output might look like:
#
#     ['deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled']
#     ['retainers', 'ternaries']
#     ['generating', 'greatening']
#     ['resmelts', 'smelters', 'termless']
#
# Hint: For each word in the word list, sort the letters and join them back into a string. Make a dictionary that maps from this sorted string to a list of words that are anagrams of it.

# %% [markdown]
# The following cells download `words.txt` and read the words into a list.

# %%
download('https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/words.txt');

# %%
word_list = open('words.txt').read().split()

# %% [markdown]
# Here's the `sort_word` function we've used before.

# %%
def sort_word(word):
    return ''.join(sorted(word))

# %%
# Solution goes here
anagram_dict = {}
for word in word_list:
    key = sort_word(word)
    #anagram_dict[key] = anagram_dict.get(key, []) + [word]
    if key not in anagram_dict:
        anagram_dict[key] = [word]
    else:
        anagram_dict[key].append(word)

# %% [markdown]
# To find the longest list of anagrams, you can use the following function, which takes a key-value pair where the key is a string and the value is a list of words.
# It returns the length of the list.

# %%
def value_length(pair):
    key, value = pair
    return len(value)

# %% [markdown]
# We can use this function as a sort key to find the longest lists of anagrams.

# %%
anagram_items = sorted(anagram_dict.items(), key=value_length)
for key, value in anagram_items[-10:]:
    print(value)
# Out:
# ['carets', 'cartes', 'caster', 'caters', 'crates', 'reacts', 'recast', 'traces']
# ['earings', 'erasing', 'gainers', 'reagins', 'regains', 'reginas', 'searing', 'seringa']
# ['lapse', 'leaps', 'pales', 'peals', 'pleas', 'salep', 'sepal', 'spale']
# ['palest', 'palets', 'pastel', 'petals', 'plates', 'pleats', 'septal', 'staple']
# ['peris', 'piers', 'pries', 'prise', 'ripes', 'speir', 'spier', 'spire']
# ['capers', 'crapes', 'escarp', 'pacers', 'parsec', 'recaps', 'scrape', 'secpar', 'spacer']
# ['estrin', 'inerts', 'insert', 'inters', 'niters', 'nitres', 'sinter', 'triens', 'trines']
# ['least', 'setal', 'slate', 'stale', 'steal', 'stela', 'taels', 'tales', 'teals', 'tesla']
# ['alerts', 'alters', 'artels', 'estral', 'laster', 'ratels', 'salter', 'slater', 'staler', 'stelar', 'talers']
# ['apers', 'asper', 'pares', 'parse', 'pears', 'prase', 'presa', 'rapes', 'reaps', 'spare', 'spear']

# %% [markdown]
# If you want to know the longest words that have anagrams, you can use the following loop to print some of them.

# %%
longest = 7

for key, value in anagram_items:
    if len(value) > 1:
        word_len = len(value[0])
        if word_len > longest:
            longest = word_len
            print(value)
# Out:
# ['abasement', 'entamebas']
# ['abreacting', 'acerbating']
# ['altercations', 'intercoastal']
# ['certification', 'rectification']
# ['certifications', 'rectifications']
# ['impressivenesses', 'permissivenesses']

# %% [markdown]
# ### Exercise
#
# Write a function called `word_distance` that takes two words with the same length and returns the number of places where the two words differ.
#
# Hint: Use `zip` to loop through the corresponding letters of the words.

# %% [markdown]
# Here's an outline of the function with doctests you can use to check your function.

# %%
def word_distance(word1, word2):
    """Computes the number of places where two word differ.

    >>> word_distance("hello", "hxllo")
    1
    >>> word_distance("ample", "apply")
    2
    >>> word_distance("kitten", "mutton")
    3
    """
    return None

# %%
# Solution goes here
def word_distance(word1, word2):
    """Computes the number of places where two word differ.

    >>> word_distance("hello", "hxllo")
    1
    >>> word_distance("ample", "apply")
    2
    >>> word_distance("kitten", "mutton")
    3
    """
    distance = 0
    for letter1, letter2 in zip(list(word1), list(word2)):
        if letter1 != letter2:
            distance += 1
    return distance

# %%
from doctest import run_docstring_examples

def run_doctests(func):
    run_docstring_examples(func, globals(), name=func.__name__)

run_doctests(word_distance)

# %% [markdown]
# ### Exercise
#
# "Metathesis" is the transposition of letters in a word.
# Two words form a "metathesis pair" if you can transform one into the other by swapping two letters, like `converse` and `conserve`.
# Write a program that finds all of the metathesis pairs in the word list.
#
# Hint: The words in a metathesis pair must be anagrams of each other.
#
# Credit: This exercise is inspired by an example at <http://puzzlers.org>.

# %%
# Solution goes here
metathesis_list = []
for key, anagrams in anagram_dict.items():
    if len(anagrams) > 1:
        for word1 in anagrams:
            for word2 in anagrams:
                if word1 != word2 and word_distance(word1, word2) == 2:
                    if (word2, word1) not in metathesis_list:
                        metathesis_list.append((word1, word2))
                        print('metathesis pair:', word1, word2)
# Out:
# metathesis pair: aah aha
# metathesis pair: aal ala
# metathesis pair: aals alas
# metathesis pair: aba baa
# metathesis pair: abas baas
# metathesis pair: abbe babe
# metathesis pair: abbes babes
# metathesis pair: bate beta
# metathesis pair: beat beta
# metathesis pair: bates betas
# metathesis pair: bates tabes
# metathesis pair: beast beats
# metathesis pair: beats betas
# metathesis pair: abide abied
# metathesis pair: able bale
# metathesis pair: bale blae
# metathesis pair: abler baler
# metathesis pair: ables bales
# metathesis pair: abmho abohm
# metathesis pair: abmhos abohms
# metathesis pair: abode adobe
# metathesis pair: abodes adobes
# metathesis pair: tabu tuba
# metathesis pair: tabus tubas
# metathesis pair: aby bay
# metathesis pair: abyed bayed
# metathesis pair: abying baying
# metathesis pair: abys bays
# metathesis pair: accouter accoutre
# metathesis pair: accouters accoutres
# metathesis pair: cade dace
# metathesis pair: acers acres
# metathesis pair: acres cares
# metathesis pair: cares carse
# metathesis pair: cares races
# metathesis pair: achier cahier
# metathesis pair: acid caid
# metathesis pair: cadi caid
# metathesis pair: acids caids
# metathesis pair: cadis caids
# metathesis pair: acme came
# metathesis pair: came mace
# metathesis pair: acmes cames
# metathesis pair: cames maces
# metathesis pair: acne cane
# metathesis pair: acned caned
# metathesis pair: acnes canes
# metathesis pair: acre care
# metathesis pair: care race
# metathesis pair: acred arced
# metathesis pair: acred cared
# metathesis pair: arced raced
# metathesis pair: cared raced
# metathesis pair: act cat
# metathesis pair: actin antic
# metathesis pair: actins antics
# metathesis pair: action cation
# metathesis pair: actions cations
# metathesis pair: castor costar
# metathesis pair: acts cats
# metathesis pair: cast cats
# metathesis pair: ad da
# metathesis pair: add dad
# metathesis pair: adds dads
# metathesis pair: pated taped
# metathesis pair: adman daman
# metathesis pair: maned menad
# metathesis pair: maned named
# metathesis pair: adze daze
# metathesis pair: adzes dazes
# metathesis pair: aerologies areologies
# metathesis pair: aerology areology
# metathesis pair: hereat reheat
# metathesis pair: aetheric hetaeric
# metathesis pair: aft fat
# metathesis pair: age gae
# metathesis pair: aged egad
# metathesis pair: aged gaed
# metathesis pair: rages sager
# metathesis pair: ages gaes
# metathesis pair: agger eggar
# metathesis pair: agger gager
# metathesis pair: aggers eggars
# metathesis pair: aggers gagers
# metathesis pair: sagger seggar
# metathesis pair: saggers seggars
# metathesis pair: agin gain
# metathesis pair: agonies agonise
# metathesis pair: eager eagre
# metathesis pair: eager ragee
# metathesis pair: eagre ragee
# metathesis pair: eagers eagres
# metathesis pair: eagers ragees
# metathesis pair: eagres ragees
# metathesis pair: ah ha
# metathesis pair: ahem haem
# metathesis pair: haem hame
# metathesis pair: aider aired
# metathesis pair: daimen maiden
# metathesis pair: dais said
# metathesis pair: sadi said
# metathesis pair: ailment aliment
# metathesis pair: ailments aliments
# metathesis pair: sail sial
# metathesis pair: aim ami
# metathesis pair: armies ramies
# metathesis pair: aims amis
# metathesis pair: aims sima
# metathesis pair: ain ani
# metathesis pair: ains anis
# metathesis pair: arising raising
# metathesis pair: resails serails
# metathesis pair: serails serials
# metathesis pair: rain rani
# metathesis pair: naris ranis
# metathesis pair: naris sarin
# metathesis pair: rains ranis
# metathesis pair: stair stria
# metathesis pair: akin kain
# metathesis pair: alan anal
# metathesis pair: alb lab
# metathesis pair: bal lab
# metathesis pair: baals balas
# metathesis pair: balas balsa
# metathesis pair: balas basal
# metathesis pair: albs labs
# metathesis pair: bals labs
# metathesis pair: alburnum laburnum
# metathesis pair: alburnums laburnums
# metathesis pair: alder lader
# metathesis pair: alders laders
# metathesis pair: aldol allod
# metathesis pair: aldols allods
# metathesis pair: alef flea
# metathesis pair: feal leaf
# metathesis pair: alefs fleas
# metathesis pair: alter artel
# metathesis pair: alter later
# metathesis pair: artel ratel
# metathesis pair: later ratel
# metathesis pair: later taler
# metathesis pair: realter relater
# metathesis pair: alters artels
# metathesis pair: artels ratels
# metathesis pair: laster salter
# metathesis pair: salter slater
# metathesis pair: slater staler
# metathesis pair: staler stelar
# metathesis pair: lase sale
# metathesis pair: leas seal
# metathesis pair: veinal venial
# metathesis pair: venial vineal
# metathesis pair: releasing resealing
# metathesis pair: algin align
# metathesis pair: algins aligns
# metathesis pair: algor argol
# metathesis pair: algors argols
# metathesis pair: algum almug
# metathesis pair: algums almugs
# metathesis pair: alien aline
# metathesis pair: aline anile
# metathesis pair: aliens alines
# metathesis pair: saline silane
# metathesis pair: dealing leading
# metathesis pair: lati tali
# metathesis pair: tail tali
# metathesis pair: alkalies alkalise
# metathesis pair: alma lama
# metathesis pair: almas lamas
# metathesis pair: alme lame
# metathesis pair: lame male
# metathesis pair: almes lames
# metathesis pair: lames males
# metathesis pair: alms lams
# metathesis pair: aloft float
# metathesis pair: float flota
# metathesis pair: alone anole
# metathesis pair: alow awol
# metathesis pair: alp lap
# metathesis pair: lap pal
# metathesis pair: penial pineal
# metathesis pair: alps laps
# metathesis pair: laps pals
# metathesis pair: pals salp
# metathesis pair: salp slap
# metathesis pair: alt lat
# metathesis pair: altar artal
# metathesis pair: artal ratal
# metathesis pair: realters relaters
# metathesis pair: loath lotah
# metathesis pair: altitude latitude
# metathesis pair: altitudes latitudes
# metathesis pair: lota tola
# metathesis pair: lotas tolas
# metathesis pair: altruism ultraism
# metathesis pair: altruisms ultraisms
# metathesis pair: altruist ultraist
# metathesis pair: altruists ultraists
# metathesis pair: alts lats
# metathesis pair: last lats
# metathesis pair: last salt
# metathesis pair: salt slat
# metathesis pair: alumin alumni
# metathesis pair: am ma
# metathesis pair: amain amnia
# metathesis pair: amnia mania
# metathesis pair: amber embar
# metathesis pair: ambers embars
# metathesis pair: bedlam beldam
# metathesis pair: marble ramble
# metathesis pair: marbles rambles
# metathesis pair: mane name
# metathesis pair: name nema
# metathesis pair: manes manse
# metathesis pair: manes names
# metathesis pair: manse mensa
# metathesis pair: names nemas
# metathesis pair: amid maid
# metathesis pair: amids maids
# metathesis pair: amigo imago
# metathesis pair: amin main
# metathesis pair: amine anime
# metathesis pair: amines animes
# metathesis pair: amins mains
# metathesis pair: amir mair
# metathesis pair: amirs mairs
# metathesis pair: ammine immane
# metathesis pair: amnic manic
# metathesis pair: amp map
# metathesis pair: map pam
# metathesis pair: ample maple
# metathesis pair: amps maps
# metathesis pair: maps pams
# metathesis pair: pams samp
# metathesis pair: an na
# metathesis pair: anas ansa
# metathesis pair: anchor archon
# metathesis pair: anchors archons
# metathesis pair: ane nae
# metathesis pair: leaden leaned
# metathesis pair: ratines retinas
# metathesis pair: retains retsina
# metathesis pair: angel angle
# metathesis pair: angels angles
# metathesis pair: ranges sanger
# metathesis pair: anil nail
# metathesis pair: lain nail
# metathesis pair: anils nails
# metathesis pair: slain snail
# metathesis pair: sanies sansei
# metathesis pair: tetanies tetanise
# metathesis pair: khans shank
# metathesis pair: anna nana
# metathesis pair: annas nanas
# metathesis pair: anoxic axonic
# metathesis pair: anserous arsenous
# metathesis pair: antes nates
# metathesis pair: antimonies antinomies
# metathesis pair: antimony antinomy
# metathesis pair: saint tains
# metathesis pair: satin stain
# metathesis pair: nival vinal
# metathesis pair: any nay
# metathesis pair: pare rape
# metathesis pair: pear reap
# metathesis pair: pares parse
# metathesis pair: pares rapes
# metathesis pair: parse prase
# metathesis pair: pears reaps
# metathesis pair: prase presa
# metathesis pair: apes apse
# metathesis pair: apse pase
# metathesis pair: apse spae
# metathesis pair: appal papal
# metathesis pair: appel apple
# metathesis pair: appels apples
# metathesis pair: apses pases
# metathesis pair: apses spaes
# metathesis pair: pases passe
# metathesis pair: apsis aspis
# metathesis pair: apt pat
# metathesis pair: pat tap
# metathesis pair: apter pater
# metathesis pair: pater taper
# metathesis pair: aptly patly
# metathesis pair: aptness patness
# metathesis pair: aptnesses patnesses
# metathesis pair: chares chaser
# metathesis pair: arcing racing
# metathesis pair: caring racing
# metathesis pair: arcked racked
# metathesis pair: carked racked
# metathesis pair: dacker racked
# metathesis pair: arcking racking
# metathesis pair: carking racking
# metathesis pair: arco orca
# metathesis pair: causers saucers
# metathesis pair: barde bared
# metathesis pair: are era
# metathesis pair: ear era
# metathesis pair: ares arse
# metathesis pair: ares eras
# metathesis pair: arse rase
# metathesis pair: ears eras
# metathesis pair: sear sera
# metathesis pair: seater teaser
# metathesis pair: argal graal
# metathesis pair: argals graals
# metathesis pair: argil grail
# metathesis pair: glair grail
# metathesis pair: argils grails
# metathesis pair: glairs grails
# metathesis pair: argon organ
# metathesis pair: groan organ
# metathesis pair: argons organs
# metathesis pair: groans organs
# metathesis pair: gaurs guars
# metathesis pair: aria raia
# metathesis pair: arias raias
# metathesis pair: arid raid
# metathesis pair: arider raider
# metathesis pair: resail serail
# metathesis pair: serail serial
# metathesis pair: treaties treatise
# metathesis pair: aril rail
# metathesis pair: lair liar
# metathesis pair: lair rail
# metathesis pair: liar lira
# metathesis pair: liar rial
# metathesis pair: rail rial
# metathesis pair: ariled railed
# metathesis pair: laired railed
# metathesis pair: arils rails
# metathesis pair: lairs liars
# metathesis pair: lairs rails
# metathesis pair: liars liras
# metathesis pair: liars rials
# metathesis pair: rails rials
# metathesis pair: arise raise
# metathesis pair: arises raises
# metathesis pair: riatas tiaras
# metathesis pair: arles rales
# metathesis pair: earls lares
# metathesis pair: lares laser
# metathesis pair: lares rales
# metathesis pair: lears reals
# metathesis pair: arm ram
# metathesis pair: mar ram
# metathesis pair: armet ramet
# metathesis pair: mater tamer
# metathesis pair: ramet tamer
# metathesis pair: armets ramets
# metathesis pair: maters matres
# metathesis pair: maters tamers
# metathesis pair: ramets tamers
# metathesis pair: armoires armories
# metathesis pair: arms rams
# metathesis pair: mars rams
# metathesis pair: arrest rarest
# metathesis pair: tarres terras
# metathesis pair: ars ras
# metathesis pair: arses rases
# metathesis pair: art rat
# metathesis pair: rat tar
# metathesis pair: strait strati
# metathesis pair: lasters salters
# metathesis pair: salters slaters
# metathesis pair: arts rats
# metathesis pair: rats tars
# metathesis pair: star tsar
# metathesis pair: arty tray
# metathesis pair: coast coats
# metathesis pair: coats costa
# metathesis pair: hassels hassles
# metathesis pair: asker eskar
# metathesis pair: asker saker
# metathesis pair: rakes saker
# metathesis pair: askers eskars
# metathesis pair: askers sakers
# metathesis pair: wakes wekas
# metathesis pair: asp sap
# metathesis pair: pas sap
# metathesis pair: sap spa
# metathesis pair: napes panes
# metathesis pair: neaps peans
# metathesis pair: sneap spean
# metathesis pair: sneaps speans
# metathesis pair: parses passer
# metathesis pair: parses prases
# metathesis pair: spares sparse
# metathesis pair: paresis parises
# metathesis pair: parises praises
# metathesis pair: asps saps
# metathesis pair: pass saps
# metathesis pair: saps spas
# metathesis pair: assert asters
# metathesis pair: serrates terrases
# metathesis pair: assertor assorter
# metathesis pair: assertors assorters
# metathesis pair: rates tares
# metathesis pair: at ta
# metathesis pair: ate eta
# metathesis pair: ate tae
# metathesis pair: eat eta
# metathesis pair: eat tae
# metathesis pair: eta tea
# metathesis pair: tae tea
# metathesis pair: ates etas
# metathesis pair: east eats
# metathesis pair: eats etas
# metathesis pair: eats sate
# metathesis pair: etas teas
# metathesis pair: sate seta
# metathesis pair: seat seta
# metathesis pair: seat teas
# metathesis pair: rattish tartish
# metathesis pair: atlas talas
# metathesis pair: osmatic somatic
# metathesis pair: atomies atomise
# metathesis pair: atoms stoma
# metathesis pair: riata tiara
# metathesis pair: nattered rattened
# metathesis pair: aunt tuna
# metathesis pair: aunts tunas
# metathesis pair: urase ursae
# metathesis pair: ureas ursae
# metathesis pair: auric curia
# metathesis pair: saliva salvia
# metathesis pair: naves vanes
# metathesis pair: raves saver
# metathesis pair: save vase
# metathesis pair: avo ova
# metathesis pair: awe wae
# metathesis pair: awes waes
# metathesis pair: awn wan
# metathesis pair: awned waned
# metathesis pair: dawen dewan
# metathesis pair: awning waning
# metathesis pair: awns wans
# metathesis pair: sawn swan
# metathesis pair: snaw swan
# metathesis pair: awny wany
# metathesis pair: awry wary
# metathesis pair: axel axle
# metathesis pair: axels axles
# metathesis pair: axemen examen
# metathesis pair: ay ya
# metathesis pair: ayes eyas
# metathesis pair: eyas yeas
# metathesis pair: babul bubal
# metathesis pair: babuls bubals
# metathesis pair: bad dab
# metathesis pair: badger barged
# metathesis pair: barged garbed
# metathesis pair: bads dabs
# metathesis pair: bag gab
# metathesis pair: bags gabs
# metathesis pair: baht bath
# metathesis pair: bahts baths
# metathesis pair: balded bladed
# metathesis pair: ban nab
# metathesis pair: bans nabs
# metathesis pair: bar bra
# metathesis pair: barbet rabbet
# metathesis pair: barbets rabbets
# metathesis pair: bard brad
# metathesis pair: bard darb
# metathesis pair: brad drab
# metathesis pair: darb drab
# metathesis pair: bards brads
# metathesis pair: bards darbs
# metathesis pair: brads drabs
# metathesis pair: darbs drabs
# metathesis pair: bare brae
# metathesis pair: bear brae
# metathesis pair: barege bargee
# metathesis pair: bareges bargees
# metathesis pair: barely barley
# metathesis pair: barer barre
# metathesis pair: bares baser
# metathesis pair: bares braes
# metathesis pair: baser saber
# metathesis pair: bears braes
# metathesis pair: saber sabre
# metathesis pair: barging garbing
# metathesis pair: baric rabic
# metathesis pair: barked braked
# metathesis pair: barkier brakier
# metathesis pair: barkiest brakiest
# metathesis pair: barking braking
# metathesis pair: barky braky
# metathesis pair: barn bran
# metathesis pair: barns brans
# metathesis pair: barret barter
# metathesis pair: barrets barters
# metathesis pair: barrette berretta
# metathesis pair: barrettes berrettas
# metathesis pair: bars bras
# metathesis pair: bas sab
# metathesis pair: base sabe
# metathesis pair: based sabed
# metathesis pair: bases sabes
# metathesis pair: basest basset
# metathesis pair: basset bastes
# metathesis pair: basin sabin
# metathesis pair: nabis sabin
# metathesis pair: basins sabins
# metathesis pair: basis bassi
# metathesis pair: bass sabs
# metathesis pair: bast bats
# metathesis pair: bats tabs
# metathesis pair: bat tab
# metathesis pair: baud daub
# metathesis pair: bauds daubs
# metathesis pair: bayadeer bayadere
# metathesis pair: bayadeers bayaderes
# metathesis pair: beam bema
# metathesis pair: beams bemas
# metathesis pair: berate rebate
# metathesis pair: berates rebates
# metathesis pair: becrust becurst
# metathesis pair: bed deb
# metathesis pair: bedlams beldams
# metathesis pair: bidder birded
# metathesis pair: bedrug redbug
# metathesis pair: bedrugged begrudged
# metathesis pair: bedrugging begrudging
# metathesis pair: bedrugs redbugs
# metathesis pair: beds debs
# metathesis pair: been bene
# metathesis pair: beer bree
# metathesis pair: beers brees
# metathesis pair: belated bleated
# metathesis pair: belt blet
# metathesis pair: belts blets
# metathesis pair: blest blets
# metathesis pair: bemire berime
# metathesis pair: berime bireme
# metathesis pair: bemired berimed
# metathesis pair: bemires berimes
# metathesis pair: berimes biremes
# metathesis pair: bemiring beriming
# metathesis pair: ben neb
# metathesis pair: bens nebs
# metathesis pair: beraking breaking
# metathesis pair: berated rebated
# metathesis pair: debater rebated
# metathesis pair: berating rebating
# metathesis pair: beslime besmile
# metathesis pair: beslimed besmiled
# metathesis pair: beslimes besmiles
# metathesis pair: besliming besmiling
# metathesis pair: best bets
# metathesis pair: bestir bister
# metathesis pair: bister bistre
# metathesis pair: bestirs bisters
# metathesis pair: bisters bistres
# metathesis pair: bestrid bistred
# metathesis pair: bestud busted
# metathesis pair: bey bye
# metathesis pair: beys byes
# metathesis pair: bibs sibb
# metathesis pair: bicorn bicron
# metathesis pair: bid dib
# metathesis pair: bids dibs
# metathesis pair: big gib
# metathesis pair: bigly bilgy
# metathesis pair: bike kibe
# metathesis pair: bikes kibes
# metathesis pair: biltong bolting
# metathesis pair: limbate timbale
# metathesis pair: bin nib
# metathesis pair: bins nibs
# metathesis pair: bionic niobic
# metathesis pair: birder birred
# metathesis pair: bis sib
# metathesis pair: blankest blankets
# metathesis pair: blast blats
# metathesis pair: blot bolt
# metathesis pair: blots bolts
# metathesis pair: blouses boluses
# metathesis pair: bluest bluets
# metathesis pair: bustle subtle
# metathesis pair: bluesy blueys
# metathesis pair: umbels umbles
# metathesis pair: blurs slurb
# metathesis pair: boar bora
# metathesis pair: boars boras
# metathesis pair: boast boats
# metathesis pair: bodies dobies
# metathesis pair: body doby
# metathesis pair: bog gob
# metathesis pair: bogan goban
# metathesis pair: bogans gobans
# metathesis pair: bogies gobies
# metathesis pair: bogs gobs
# metathesis pair: bogy goby
# metathesis pair: bolar lobar
# metathesis pair: labor lobar
# metathesis pair: bolder bordel
# metathesis pair: bole lobe
# metathesis pair: boles lobes
# metathesis pair: bolo lobo
# metathesis pair: bolos lobos
# metathesis pair: bolster lobster
# metathesis pair: bolsters lobsters
# metathesis pair: bombed mobbed
# metathesis pair: bomber mobber
# metathesis pair: bombers mobbers
# metathesis pair: bombing mobbing
# metathesis pair: bonus bosun
# metathesis pair: booger goober
# metathesis pair: boogers goobers
# metathesis pair: boor broo
# metathesis pair: boors broos
# metathesis pair: boost boots
# metathesis pair: bore robe
# metathesis pair: bored robed
# metathesis pair: orbed robed
# metathesis pair: bores robes
# metathesis pair: robes sober
# metathesis pair: boring robing
# metathesis pair: orbing robing
# metathesis pair: bos sob
# metathesis pair: boss sobs
# metathesis pair: botanies botanise
# metathesis pair: unrobes unsober
# metathesis pair: brag grab
# metathesis pair: garb grab
# metathesis pair: brags grabs
# metathesis pair: garbs grabs
# metathesis pair: brede breed
# metathesis pair: bredes breeds
# metathesis pair: dibber ribbed
# metathesis pair: fiber fibre
# metathesis pair: fibers fibres
# metathesis pair: briskest briskets
# metathesis pair: omber ombre
# metathesis pair: ombers ombres
# metathesis pair: somber sombre
# metathesis pair: bromo broom
# metathesis pair: bromos brooms
# metathesis pair: brugh burgh
# metathesis pair: brughs burghs
# metathesis pair: bruin burin
# metathesis pair: bruins burins
# metathesis pair: buries busier
# metathesis pair: buries rubies
# metathesis pair: brunet burnet
# metathesis pair: brunets burnets
# metathesis pair: brunt burnt
# metathesis pair: bud dub
# metathesis pair: buds dubs
# metathesis pair: bugle bulge
# metathesis pair: bugled bulged
# metathesis pair: bugler bulger
# metathesis pair: buglers bulgers
# metathesis pair: bugles bulges
# metathesis pair: bugling bulging
# metathesis pair: bun nub
# metathesis pair: buns nubs
# metathesis pair: bur rub
# metathesis pair: unbar urban
# metathesis pair: buras bursa
# metathesis pair: burble rubble
# metathesis pair: burbled rubbled
# metathesis pair: burbles rubbles
# metathesis pair: burblier rubblier
# metathesis pair: burbliest rubbliest
# metathesis pair: burbling rubbling
# metathesis pair: burbly rubbly
# metathesis pair: burden burned
# metathesis pair: buried rubied
# metathesis pair: burier rubier
# metathesis pair: burkes busker
# metathesis pair: burs rubs
# metathesis pair: rebus rubes
# metathesis pair: rubes suber
# metathesis pair: bury ruby
# metathesis pair: burying rubying
# metathesis pair: bus sub
# metathesis pair: buss subs
# metathesis pair: bust buts
# metathesis pair: buts tubs
# metathesis pair: cubist cubits
# metathesis pair: busy buys
# metathesis pair: but tub
# metathesis pair: cadaster cadastre
# metathesis pair: cadasters cadastres
# metathesis pair: cades cased
# metathesis pair: cades daces
# metathesis pair: sacred scared
# metathesis pair: caestus cuestas
# metathesis pair: cafe face
# metathesis pair: cafes faces
# metathesis pair: caliber calibre
# metathesis pair: calibers calibres
# metathesis pair: calk lack
# metathesis pair: calked lacked
# metathesis pair: calker lacker
# metathesis pair: calkers lackers
# metathesis pair: calking lacking
# metathesis pair: calks lacks
# metathesis pair: caller cellar
# metathesis pair: callers cellars
# metathesis pair: calm clam
# metathesis pair: calms clams
# metathesis pair: calque claque
# metathesis pair: calques claques
# metathesis pair: calve clave
# metathesis pair: cam mac
# metathesis pair: caramel ceramal
# metathesis pair: cams macs
# metathesis pair: discanted distanced
# metathesis pair: caners casern
# metathesis pair: canine cannie
# metathesis pair: ceratins creatins
# metathesis pair: cannot canton
# metathesis pair: canst cants
# metathesis pair: decanter recanted
# metathesis pair: cantor carton
# metathesis pair: carton craton
# metathesis pair: cantors cartons
# metathesis pair: cartons cratons
# metathesis pair: cap pac
# metathesis pair: cape pace
# metathesis pair: caped paced
# metathesis pair: caper pacer
# metathesis pair: capers pacers
# metathesis pair: capes paces
# metathesis pair: scape space
# metathesis pair: caps pacs
# metathesis pair: caption paction
# metathesis pair: captions pactions
# metathesis pair: captor cartop
# metathesis pair: caramels ceramals
# metathesis pair: carbon corban
# metathesis pair: carbons corbans
# metathesis pair: triacids triadics
# metathesis pair: carer racer
# metathesis pair: carers racers
# metathesis pair: caress carses
# metathesis pair: carses crases
# metathesis pair: caret carte
# metathesis pair: caret cater
# metathesis pair: carte crate
# metathesis pair: crate trace
# metathesis pair: carets cartes
# metathesis pair: carets caters
# metathesis pair: cartes caster
# metathesis pair: cartes crates
# metathesis pair: crates traces
# metathesis pair: caries cerias
# metathesis pair: cark rack
# metathesis pair: carks racks
# metathesis pair: carn narc
# metathesis pair: carns narcs
# metathesis pair: carol coral
# metathesis pair: carols corals
# metathesis pair: carp crap
# metathesis pair: carped craped
# metathesis pair: carpel parcel
# metathesis pair: carpels parcels
# metathesis pair: scarper scraper
# metathesis pair: carping craping
# metathesis pair: scarping scraping
# metathesis pair: carps craps
# metathesis pair: scarp scrap
# metathesis pair: carted crated
# metathesis pair: crated traced
# metathesis pair: carter crater
# metathesis pair: crater tracer
# metathesis pair: carters craters
# metathesis pair: craters tracers
# metathesis pair: carting crating
# metathesis pair: crating tracing
# metathesis pair: carve crave
# metathesis pair: carved craved
# metathesis pair: carven craven
# metathesis pair: carver craver
# metathesis pair: carvers cravers
# metathesis pair: carves craves
# metathesis pair: carving craving
# metathesis pair: carvings cravings
# metathesis pair: cascabel cascable
# metathesis pair: cascabels cascables
# metathesis pair: cascade saccade
# metathesis pair: cascades saccades
# metathesis pair: chases chasse
# metathesis pair: cask sack
# metathesis pair: casked sacked
# metathesis pair: casking sacking
# metathesis pair: casks sacks
# metathesis pair: casque sacque
# metathesis pair: casques sacques
# metathesis pair: cassock cossack
# metathesis pair: cassocks cossacks
# metathesis pair: caste cesta
# metathesis pair: cates taces
# metathesis pair: castes cestas
# metathesis pair: castors costars
# metathesis pair: casual causal
# metathesis pair: casually causally
# metathesis pair: casuals causals
# metathesis pair: cate tace
# metathesis pair: cerated created
# metathesis pair: recrate retrace
# metathesis pair: retrace terrace
# metathesis pair: recrates retraces
# metathesis pair: retraces terraces
# metathesis pair: cause sauce
# metathesis pair: caused sauced
# metathesis pair: causer saucer
# metathesis pair: causes sauces
# metathesis pair: causing saucing
# metathesis pair: ceder cered
# metathesis pair: cered creed
# metathesis pair: center centre
# metathesis pair: decenter decentre
# metathesis pair: centers centres
# metathesis pair: cento conte
# metathesis pair: centos contes
# metathesis pair: cerate create
# metathesis pair: cerates creates
# metathesis pair: ceratin certain
# metathesis pair: ceratin creatin
# metathesis pair: cerci ceric
# metathesis pair: ceruse recuse
# metathesis pair: recuse secure
# metathesis pair: cerite recite
# metathesis pair: cerites recites
# metathesis pair: cero core
# metathesis pair: ceros cores
# metathesis pair: cores corse
# metathesis pair: course source
# metathesis pair: certes terces
# metathesis pair: certification rectification
# metathesis pair: certifications rectifications
# metathesis pair: certified rectified
# metathesis pair: certifier rectifier
# metathesis pair: certifiers rectifiers
# metathesis pair: certifies rectifies
# metathesis pair: certify rectify
# metathesis pair: certifying rectifying
# metathesis pair: certitude rectitude
# metathesis pair: certitudes rectitudes
# metathesis pair: ceruses recuses
# metathesis pair: recuses secures
# metathesis pair: cervices crevices
# metathesis pair: cess secs
# metathesis pair: latches satchel
# metathesis pair: chams chasm
# metathesis pair: chancres cranches
# metathesis pair: snatcher stancher
# metathesis pair: snatch stanch
# metathesis pair: sachet taches
# metathesis pair: snatches stanches
# metathesis pair: chicle cliche
# metathesis pair: chicles cliches
# metathesis pair: chiel chile
# metathesis pair: chiels chiles
# metathesis pair: chiles chisel
# metathesis pair: inched niched
# metathesis pair: inches niches
# metathesis pair: inching niching
# metathesis pair: chopine phocine
# metathesis pair: ocher ochre
# metathesis pair: oraches roaches
# metathesis pair: ochers ochres
# metathesis pair: citherns cithrens
# metathesis pair: cider dicer
# metathesis pair: dicer riced
# metathesis pair: ciders dicers
# metathesis pair: cine nice
# metathesis pair: cion coin
# metathesis pair: cion icon
# metathesis pair: coin coni
# metathesis pair: cions coins
# metathesis pair: cions icons
# metathesis pair: cipolin picolin
# metathesis pair: cipolins picolins
# metathesis pair: cithern cithren
# metathesis pair: tetracid tetradic
# metathesis pair: citrin nitric
# metathesis pair: clanged glanced
# metathesis pair: clanging glancing
# metathesis pair: claps clasp
# metathesis pair: clematis climates
# metathesis pair: clod cold
# metathesis pair: clods colds
# metathesis pair: closest closets
# metathesis pair: clot colt
# metathesis pair: clots colts
# metathesis pair: cloy coly
# metathesis pair: clutch cultch
# metathesis pair: clutches cultches
# metathesis pair: coal cola
# metathesis pair: cola loca
# metathesis pair: coals colas
# metathesis pair: coax coxa
# metathesis pair: cod doc
# metathesis pair: codder corded
# metathesis pair: code coed
# metathesis pair: coden coned
# metathesis pair: coder cored
# metathesis pair: codes coeds
# metathesis pair: codex coxed
# metathesis pair: cods docs
# metathesis pair: cohered ochered
# metathesis pair: cohering ochering
# metathesis pair: fico foci
# metathesis pair: coinfer conifer
# metathesis pair: coinfers conifers
# metathesis pair: collide collied
# metathesis pair: colonies colonise
# metathesis pair: combat tombac
# metathesis pair: combats tombacs
# metathesis pair: comet comte
# metathesis pair: comets comtes
# metathesis pair: compeer compere
# metathesis pair: compeers comperes
# metathesis pair: compiled complied
# metathesis pair: compiler complier
# metathesis pair: compilers compliers
# metathesis pair: compiles complies
# metathesis pair: complaint compliant
# metathesis pair: concent connect
# metathesis pair: concents connects
# metathesis pair: concerted concreted
# metathesis pair: concerting concreting
# metathesis pair: condoles consoled
# metathesis pair: condor cordon
# metathesis pair: condors cordons
# metathesis pair: conk nock
# metathesis pair: conked nocked
# metathesis pair: conking nocking
# metathesis pair: conks nocks
# metathesis pair: conservation conversation
# metathesis pair: conservations conversations
# metathesis pair: conserve converse
# metathesis pair: conserved conversed
# metathesis pair: conserves converses
# metathesis pair: conserving conversing
# metathesis pair: copes copse
# metathesis pair: copula cupola
# metathesis pair: copulas cupolas
# metathesis pair: cork rock
# metathesis pair: corked rocked
# metathesis pair: docker rocked
# metathesis pair: corker rocker
# metathesis pair: corkers rockers
# metathesis pair: corkier rockier
# metathesis pair: corkiest rockiest
# metathesis pair: corking rocking
# metathesis pair: corklike rocklike
# metathesis pair: corks rocks
# metathesis pair: corky rocky
# metathesis pair: corny crony
# metathesis pair: coroner crooner
# metathesis pair: coroners crooners
# metathesis pair: corps crops
# metathesis pair: electors electros
# metathesis pair: rectos sector
# metathesis pair: coset cotes
# metathesis pair: cost cots
# metathesis pair: costumer customer
# metathesis pair: costumers customers
# metathesis pair: cosy coys
# metathesis pair: coude douce
# metathesis pair: courses sources
# metathesis pair: couth touch
# metathesis pair: couther toucher
# metathesis pair: couthier touchier
# metathesis pair: couthiest touchiest
# metathesis pair: coves voces
# metathesis pair: lascar rascal
# metathesis pair: crafted fracted
# metathesis pair: recrated retraced
# metathesis pair: retraced terraced
# metathesis pair: recrating retracing
# metathesis pair: retracing terracing
# metathesis pair: creep crepe
# metathesis pair: creeps crepes
# metathesis pair: creepy crepey
# metathesis pair: crud curd
# metathesis pair: cruds curds
# metathesis pair: cruet curet
# metathesis pair: cruet eruct
# metathesis pair: curet cuter
# metathesis pair: eruct truce
# metathesis pair: cruets curets
# metathesis pair: cruets eructs
# metathesis pair: eructs truces
# metathesis pair: rectus recuts
# metathesis pair: crus curs
# metathesis pair: cruse curse
# metathesis pair: cures curse
# metathesis pair: cruses curses
# metathesis pair: curses cusser
# metathesis pair: crust curst
# metathesis pair: cud duc
# metathesis pair: cuds ducs
# metathesis pair: cumin mucin
# metathesis pair: cumins mucins
# metathesis pair: cups cusp
# metathesis pair: curacao curacoa
# metathesis pair: curacaos curacoas
# metathesis pair: curdier curried
# metathesis pair: curtesy curtsey
# metathesis pair: cusk suck
# metathesis pair: cusks sucks
# metathesis pair: cutesy cuteys
# metathesis pair: cylix xylic
# metathesis pair: dabbler rabbled
# metathesis pair: daddles saddled
# metathesis pair: dafter rafted
# metathesis pair: farted rafted
# metathesis pair: dag gad
# metathesis pair: dagger ragged
# metathesis pair: dags gads
# metathesis pair: dah had
# metathesis pair: dahs dash
# metathesis pair: dairies diaries
# metathesis pair: dairy diary
# metathesis pair: dairy yaird
# metathesis pair: hankered harkened
# metathesis pair: dale lade
# metathesis pair: deal lead
# metathesis pair: dales lades
# metathesis pair: deals leads
# metathesis pair: lades lased
# metathesis pair: dalles ladles
# metathesis pair: dallier rallied
# metathesis pair: dallies sallied
# metathesis pair: dam mad
# metathesis pair: dame made
# metathesis pair: dammer rammed
# metathesis pair: demander remanded
# metathesis pair: damper ramped
# metathesis pair: dams mads
# metathesis pair: monads nomads
# metathesis pair: danger gander
# metathesis pair: danger ranged
# metathesis pair: gander garden
# metathesis pair: dangered gandered
# metathesis pair: gandered gardened
# metathesis pair: dangering gandering
# metathesis pair: gandering gardening
# metathesis pair: dangers ganders
# metathesis pair: ganders gardens
# metathesis pair: danker darken
# metathesis pair: danker ranked
# metathesis pair: darken narked
# metathesis pair: narked ranked
# metathesis pair: dap pad
# metathesis pair: dapper rapped
# metathesis pair: daps pads
# metathesis pair: dear read
# metathesis pair: dears reads
# metathesis pair: darling larding
# metathesis pair: darn nard
# metathesis pair: nard rand
# metathesis pair: darns nards
# metathesis pair: nards rands
# metathesis pair: dart drat
# metathesis pair: drat trad
# metathesis pair: darts drats
# metathesis pair: shader shared
# metathesis pair: dashes sadhes
# metathesis pair: dashes sashed
# metathesis pair: sadhes sashed
# metathesis pair: dater rated
# metathesis pair: rated tared
# metathesis pair: dates sated
# metathesis pair: stade tsade
# metathesis pair: doat toad
# metathesis pair: doats toads
# metathesis pair: daw wad
# metathesis pair: dawdle waddle
# metathesis pair: dawdled waddled
# metathesis pair: dawdler waddler
# metathesis pair: dawdlers waddlers
# metathesis pair: dawdles waddles
# metathesis pair: dawdling waddling
# metathesis pair: dawed waded
# metathesis pair: dawing wading
# metathesis pair: daws wads
# metathesis pair: deaden deaned
# metathesis pair: dealer leader
# metathesis pair: dealers leaders
# metathesis pair: dealings leadings
# metathesis pair: dearer reader
# metathesis pair: dearer reared
# metathesis pair: reader reared
# metathesis pair: redear reread
# metathesis pair: redates sedater
# metathesis pair: dearies readies
# metathesis pair: hardest hardset
# metathesis pair: deary deray
# metathesis pair: deary ready
# metathesis pair: deceiver received
# metathesis pair: decenters decentres
# metathesis pair: deckel deckle
# metathesis pair: deckels deckles
# metathesis pair: decker recked
# metathesis pair: decliner reclined
# metathesis pair: recedes seceder
# metathesis pair: radicel radicle
# metathesis pair: radicels radicles
# metathesis pair: dedans desand
# metathesis pair: sadden sanded
# metathesis pair: deuced educed
# metathesis pair: deduces seduced
# metathesis pair: deem deme
# metathesis pair: deem meed
# metathesis pair: deems demes
# metathesis pair: deems meeds
# metathesis pair: deep peed
# metathesis pair: deer dere
# metathesis pair: deer dree
# metathesis pair: deer reed
# metathesis pair: dere dree
# metathesis pair: dere rede
# metathesis pair: rede reed
# metathesis pair: deers drees
# metathesis pair: deers reeds
# metathesis pair: redes reeds
# metathesis pair: redes seder
# metathesis pair: seder sered
# metathesis pair: dees seed
# metathesis pair: defacer refaced
# metathesis pair: defer refed
# metathesis pair: deferrer referred
# metathesis pair: defiler refiled
# metathesis pair: definer refined
# metathesis pair: deflower reflowed
# metathesis pair: deformer reformed
# metathesis pair: degrader regraded
# metathesis pair: regarded regraded
# metathesis pair: dei die
# metathesis pair: deification edification
# metathesis pair: deifications edifications
# metathesis pair: deified edified
# metathesis pair: deifier edifier
# metathesis pair: deifier reified
# metathesis pair: deifies edifies
# metathesis pair: deify edify
# metathesis pair: deifying edifying
# metathesis pair: signed singed
# metathesis pair: deil deli
# metathesis pair: deil diel
# metathesis pair: diel lied
# metathesis pair: deils delis
# metathesis pair: idles isled
# metathesis pair: diets dites
# metathesis pair: dites sited
# metathesis pair: dites tides
# metathesis pair: sited stied
# metathesis pair: del led
# metathesis pair: eld led
# metathesis pair: delayer relayed
# metathesis pair: sleeted steeled
# metathesis pair: listed silted
# metathesis pair: deliver relived
# metathesis pair: relived reviled
# metathesis pair: silvered slivered
# metathesis pair: lasted salted
# metathesis pair: salted slated
# metathesis pair: slated staled
# metathesis pair: insouled unsoiled
# metathesis pair: demies demise
# metathesis pair: demo dome
# metathesis pair: dome mode
# metathesis pair: demos domes
# metathesis pair: domes modes
# metathesis pair: denes dense
# metathesis pair: denotation detonation
# metathesis pair: denotations detonations
# metathesis pair: dens send
# metathesis pair: send sned
# metathesis pair: denser sender
# metathesis pair: dent tend
# metathesis pair: dented tended
# metathesis pair: indent intend
# metathesis pair: denting tending
# metathesis pair: indents intends
# metathesis pair: dents tends
# metathesis pair: deny dyne
# metathesis pair: parted prated
# metathesis pair: deposer reposed
# metathesis pair: podites posited
# metathesis pair: posited sopited
# metathesis pair: desired resided
# metathesis pair: deviser revised
# metathesis pair: derries redries
# metathesis pair: derries serried
# metathesis pair: desirer resider
# metathesis pair: desirers residers
# metathesis pair: derry redry
# metathesis pair: desert deters
# metathesis pair: discreet discrete
# metathesis pair: deserver reserved
# metathesis pair: reserved reversed
# metathesis pair: desex dexes
# metathesis pair: dexes sexed
# metathesis pair: designer resigned
# metathesis pair: desire reside
# metathesis pair: desires resides
# metathesis pair: desiring residing
# metathesis pair: diploes dipoles
# metathesis pair: detailer retailed
# metathesis pair: detainer retained
# metathesis pair: netted tented
# metathesis pair: detester retested
# metathesis pair: routed toured
# metathesis pair: deuce educe
# metathesis pair: deuces educes
# metathesis pair: deucing educing
# metathesis pair: devon doven
# metathesis pair: devons dovens
# metathesis pair: dew wed
# metathesis pair: dews weds
# metathesis pair: dey dye
# metathesis pair: deys dyes
# metathesis pair: dicker ricked
# metathesis pair: diddler riddled
# metathesis pair: didoes diodes
# metathesis pair: dies ides
# metathesis pair: ediles elides
# metathesis pair: diet dite
# metathesis pair: diet tied
# metathesis pair: dite tide
# metathesis pair: tide tied
# metathesis pair: differ riffed
# metathesis pair: dig gid
# metathesis pair: digger rigged
# metathesis pair: dignifies signified
# metathesis pair: digs gids
# metathesis pair: dim mid
# metathesis pair: dimer rimed
# metathesis pair: mired rimed
# metathesis pair: dimmer rimmed
# metathesis pair: dims mids
# metathesis pair: dine nide
# metathesis pair: dined nided
# metathesis pair: dines nides
# metathesis pair: dingles singled
# metathesis pair: dining niding
# metathesis pair: dink kind
# metathesis pair: dinkly kindly
# metathesis pair: dinks kinds
# metathesis pair: diol idol
# metathesis pair: diols idols
# metathesis pair: sloid solid
# metathesis pair: soldi solid
# metathesis pair: diopter dioptre
# metathesis pair: diopters dioptres
# metathesis pair: diploe dipole
# metathesis pair: dipper ripped
# metathesis pair: dire ride
# metathesis pair: direr drier
# metathesis pair: direr rider
# metathesis pair: direst driest
# metathesis pair: dirge ridge
# metathesis pair: dirges ridges
# metathesis pair: discanting distancing
# metathesis pair: dispel lisped
# metathesis pair: sliped spiled
# metathesis pair: dissention distension
# metathesis pair: dissentions distensions
# metathesis pair: dive vide
# metathesis pair: vide vied
# metathesis pair: diver rived
# metathesis pair: do od
# metathesis pair: dobber robbed
# metathesis pair: dodder rodded
# metathesis pair: dodged godded
# metathesis pair: dodging godding
# metathesis pair: doe ode
# metathesis pair: redo rode
# metathesis pair: doser rosed
# metathesis pair: does dose
# metathesis pair: does odes
# metathesis pair: dog god
# metathesis pair: doglike godlike
# metathesis pair: dogs gods
# metathesis pair: dole lode
# metathesis pair: doles lodes
# metathesis pair: doles soled
# metathesis pair: dols sold
# metathesis pair: dolt told
# metathesis pair: dom mod
# metathesis pair: domal modal
# metathesis pair: doms mods
# metathesis pair: don nod
# metathesis pair: done node
# metathesis pair: dongola gondola
# metathesis pair: dongolas gondolas
# metathesis pair: dons nods
# metathesis pair: doom mood
# metathesis pair: dooms moods
# metathesis pair: door odor
# metathesis pair: door rood
# metathesis pair: doorless odorless
# metathesis pair: doors odors
# metathesis pair: doors roods
# metathesis pair: doper roped
# metathesis pair: pored roped
# metathesis pair: dor rod
# metathesis pair: dormancies mordancies
# metathesis pair: dormancy mordancy
# metathesis pair: dormant mordant
# metathesis pair: dorp drop
# metathesis pair: drop prod
# metathesis pair: dorps drops
# metathesis pair: drops prods
# metathesis pair: dors rods
# metathesis pair: dors sord
# metathesis pair: dos ods
# metathesis pair: dos sod
# metathesis pair: doss sods
# metathesis pair: sloids solids
# metathesis pair: dost dots
# metathesis pair: dots tods
# metathesis pair: dot tod
# metathesis pair: dottel dottle
# metathesis pair: dottel lotted
# metathesis pair: dottels dottles
# metathesis pair: dotter rotted
# metathesis pair: doty tody
# metathesis pair: douser roused
# metathesis pair: roused soured
# metathesis pair: douses soused
# metathesis pair: dowel lowed
# metathesis pair: dower rowed
# metathesis pair: dowries rowdies
# metathesis pair: dowry rowdy
# metathesis pair: rowdy wordy
# metathesis pair: drabbest drabbets
# metathesis pair: drag grad
# metathesis pair: drags grads
# metathesis pair: laird liard
# metathesis pair: lairds liards
# metathesis pair: pared raped
# metathesis pair: spader spared
# metathesis pair: warder warred
# metathesis pair: rogued rouged
# metathesis pair: drugged grudged
# metathesis pair: drugging grudging
# metathesis pair: drupe prude
# metathesis pair: drupes prudes
# metathesis pair: dubber rubbed
# metathesis pair: ducker rucked
# metathesis pair: duds sudd
# metathesis pair: dues sued
# metathesis pair: sued used
# metathesis pair: duffel duffle
# metathesis pair: duffel luffed
# metathesis pair: duffels duffles
# metathesis pair: duffer ruffed
# metathesis pair: dune nude
# metathesis pair: nude unde
# metathesis pair: dunes nudes
# metathesis pair: dunged nudged
# metathesis pair: dunging nudging
# metathesis pair: united untied
# metathesis pair: duo oud
# metathesis pair: duo udo
# metathesis pair: duos ouds
# metathesis pair: duos udos
# metathesis pair: dup pud
# metathesis pair: dups puds
# metathesis pair: dure rude
# metathesis pair: rude rued
# metathesis pair: duster rusted
# metathesis pair: dwindles swindled
# metathesis pair: widen wined
# metathesis pair: dyker ryked
# metathesis pair: gelate legate
# metathesis pair: gelates legates
# metathesis pair: reagin regain
# metathesis pair: reagins regains
# metathesis pair: lear real
# metathesis pair: leasers sealers
# metathesis pair: earns nares
# metathesis pair: theaters theatres
# metathesis pair: seaters teasers
# metathesis pair: teasers tessera
# metathesis pair: seating teasing
# metathesis pair: eath hate
# metathesis pair: haet hate
# metathesis pair: haet heat
# metathesis pair: ebonies ebonise
# metathesis pair: pedicels pedicles
# metathesis pair: edile elide
# metathesis pair: eel lee
# metathesis pair: eels lees
# metathesis pair: lees seel
# metathesis pair: eery eyre
# metathesis pair: eyer eyre
# metathesis pair: eft fet
# metathesis pair: efts fets
# metathesis pair: egest geest
# metathesis pair: egests geests
# metathesis pair: regelate relegate
# metathesis pair: regelates relegates
# metathesis pair: eh he
# metathesis pair: ekes skee
# metathesis pair: seek skee
# metathesis pair: elan lean
# metathesis pair: elans leans
# metathesis pair: leaviest vealiest
# metathesis pair: elector electro
# metathesis pair: electrode electroed
# metathesis pair: elegies elegise
# metathesis pair: elegist elegits
# metathesis pair: elk lek
# metathesis pair: elks leks
# metathesis pair: eloin olein
# metathesis pair: eloins oleins
# metathesis pair: eludes leudes
# metathesis pair: elver lever
# metathesis pair: lever revel
# metathesis pair: elvers levers
# metathesis pair: levers revels
# metathesis pair: em me
# metathesis pair: seem seme
# metathesis pair: regimes remiges
# metathesis pair: mire rime
# metathesis pair: mires miser
# metathesis pair: mires rimes
# metathesis pair: mite time
# metathesis pair: emits smite
# metathesis pair: metis mites
# metathesis pair: mites times
# metathesis pair: smite stime
# metathesis pair: emprise imprese
# metathesis pair: premies premise
# metathesis pair: emprises impreses
# metathesis pair: encoder encored
# metathesis pair: endue undee
# metathesis pair: endues ensued
# metathesis pair: endures ensured
# metathesis pair: energies energise
# metathesis pair: enisle ensile
# metathesis pair: enisled ensiled
# metathesis pair: enisles ensiles
# metathesis pair: enisling ensiling
# metathesis pair: leno lone
# metathesis pair: enologies neologies
# metathesis pair: enology neology
# metathesis pair: essoin ossein
# metathesis pair: noesis noises
# metathesis pair: enrol nerol
# metathesis pair: enrols nerols
# metathesis pair: terreen terrene
# metathesis pair: terreens terrenes
# metathesis pair: tenia tinea
# metathesis pair: entires entries
# metathesis pair: latrines ratlines
# metathesis pair: eons noes
# metathesis pair: eons sone
# metathesis pair: noes nose
# metathesis pair: noes ones
# metathesis pair: nose sone
# metathesis pair: phase shape
# metathesis pair: epics spice
# metathesis pair: epos opes
# metathesis pair: peso pose
# metathesis pair: epoxide epoxied
# metathesis pair: er re
# metathesis pair: ere ree
# metathesis pair: goer gore
# metathesis pair: gore ogre
# metathesis pair: eros ores
# metathesis pair: ores roes
# metathesis pair: roes rose
# metathesis pair: rose sore
# metathesis pair: ers res
# metathesis pair: res ser
# metathesis pair: seers seres
# metathesis pair: erst rest
# metathesis pair: rest rets
# metathesis pair: rogue rouge
# metathesis pair: rogues rouges
# metathesis pair: liver livre
# metathesis pair: liver viler
# metathesis pair: livers livres
# metathesis pair: silver sliver
# metathesis pair: eses sees
# metathesis pair: lapises lipases
# metathesis pair: sprite stripe
# metathesis pair: sprites stripes
# metathesis pair: stirpes stripes
# metathesis pair: essoins osseins
# metathesis pair: reest reset
# metathesis pair: steer stere
# metathesis pair: reests resets
# metathesis pair: steers steres
# metathesis pair: ptoses stopes
# metathesis pair: insert inters
# metathesis pair: inters niters
# metathesis pair: niters nitres
# metathesis pair: triens trines
# metathesis pair: loiters toilers
# metathesis pair: russet tusser
# metathesis pair: etched teched
# metathesis pair: there three
# metathesis pair: theres threes
# metathesis pair: shote those
# metathesis pair: eulogies eulogise
# metathesis pair: roues rouse
# metathesis pair: eve vee
# metathesis pair: neves seven
# metathesis pair: ever veer
# metathesis pair: revest revets
# metathesis pair: verset verste
# metathesis pair: every veery
# metathesis pair: eves vees
# metathesis pair: evil veil
# metathesis pair: live vile
# metathesis pair: eviler veiler
# metathesis pair: relive revile
# metathesis pair: lively vilely
# metathesis pair: liveness vileness
# metathesis pair: livenesses vilenesses
# metathesis pair: evils veils
# metathesis pair: ewe wee
# metathesis pair: ewer weer
# metathesis pair: weer were
# metathesis pair: sewer sweer
# metathesis pair: ewes wees
# metathesis pair: example exempla
# metathesis pair: except expect
# metathesis pair: excepted expected
# metathesis pair: excepting expecting
# metathesis pair: excepts expects
# metathesis pair: excides excised
# metathesis pair: exist exits
# metathesis pair: exploder explored
# metathesis pair: eyen eyne
# metathesis pair: eyers eyres
# metathesis pair: fader fared
# metathesis pair: fain naif
# metathesis pair: fair fiar
# metathesis pair: fairs fiars
# metathesis pair: fakir kafir
# metathesis pair: fakirs kafirs
# metathesis pair: falcon flacon
# metathesis pair: falcons flacons
# metathesis pair: faltboat flatboat
# metathesis pair: faltboats flatboats
# metathesis pair: fare frae
# metathesis pair: fear frae
# metathesis pair: farmable framable
# metathesis pair: farmed framed
# metathesis pair: farmer framer
# metathesis pair: farmers framers
# metathesis pair: farming framing
# metathesis pair: faro fora
# metathesis pair: fart frat
# metathesis pair: fart raft
# metathesis pair: farting rafting
# metathesis pair: farts frats
# metathesis pair: farts rafts
# metathesis pair: fast fats
# metathesis pair: fate feta
# metathesis pair: feat feta
# metathesis pair: fates fetas
# metathesis pair: feast feats
# metathesis pair: feats fetas
# metathesis pair: fealty featly
# metathesis pair: reefed refeed
# metathesis pair: feel flee
# metathesis pair: feeling fleeing
# metathesis pair: feels flees
# metathesis pair: feet fete
# metathesis pair: felid filed
# metathesis pair: field filed
# metathesis pair: filed flied
# metathesis pair: felt left
# metathesis pair: felts lefts
# metathesis pair: femur fumer
# metathesis pair: femurs fumers
# metathesis pair: fer ref
# metathesis pair: fere free
# metathesis pair: feres frees
# metathesis pair: ferine refine
# metathesis pair: ferlies reflies
# metathesis pair: refiles reflies
# metathesis pair: ferly refly
# metathesis pair: ferried refried
# metathesis pair: refired refried
# metathesis pair: ferries refries
# ...
# metathesis pair: puree rupee
# metathesis pair: pus sup
# metathesis pair: pus ups
# metathesis pair: puses supes
# metathesis pair: spues supes
# metathesis pair: puss sups
# metathesis pair: put tup
# metathesis pair: puts tups
# metathesis pair: quais quasi
# metathesis pair: quarte quatre
# metathesis pair: quartes quatres
# metathesis pair: questionnaire questionniare
# metathesis pair: questionnaires questionniares
# metathesis pair: quickest quickset
# metathesis pair: quiet quite
# metathesis pair: quinnat quintan
# metathesis pair: quinnats quintans
# metathesis pair: racket tacker
# metathesis pair: rackets tackers
# metathesis pair: ragtag tagrag
# metathesis pair: ragtags tagrags
# metathesis pair: rallies sallier
# metathesis pair: ramsons ransoms
# metathesis pair: randies sandier
# metathesis pair: tarns trans
# metathesis pair: rate tare
# metathesis pair: tarre terra
# metathesis pair: ratine retina
# metathesis pair: rato rota
# metathesis pair: rato taro
# metathesis pair: rota tora
# metathesis pair: taro tora
# metathesis pair: ratos rotas
# metathesis pair: ratos taros
# metathesis pair: rotas toras
# metathesis pair: taros toras
# metathesis pair: rattan tartan
# metathesis pair: rattans tartans
# metathesis pair: ratted tarted
# metathesis pair: ratter tarter
# metathesis pair: ratting tarting
# metathesis pair: rattly tartly
# metathesis pair: ravages savager
# metathesis pair: raw war
# metathesis pair: rawer warer
# metathesis pair: tawers waters
# metathesis pair: raws wars
# metathesis pair: ray rya
# metathesis pair: ray yar
# metathesis pair: rays ryas
# metathesis pair: redears rereads
# metathesis pair: saltier saltire
# metathesis pair: saltier slatier
# metathesis pair: saltiers saltires
# metathesis pair: scepter sceptre
# metathesis pair: scepter specter
# metathesis pair: sceptre spectre
# metathesis pair: specter spectre
# metathesis pair: recourse resource
# metathesis pair: recourses resources
# metathesis pair: recused secured
# metathesis pair: reduces seducer
# metathesis pair: recusing securing
# metathesis pair: scarped scraped
# metathesis pair: redden rended
# metathesis pair: rees seer
# metathesis pair: seer sere
# metathesis pair: reeved veered
# metathesis pair: reeving veering
# metathesis pair: regarding regrading
# metathesis pair: regelated relegated
# metathesis pair: regelating relegating
# metathesis pair: renigs resign
# metathesis pair: signer singer
# metathesis pair: resin risen
# metathesis pair: resin serin
# metathesis pair: risen siren
# metathesis pair: serin siren
# metathesis pair: reiver riever
# metathesis pair: reivers rievers
# metathesis pair: released resealed
# metathesis pair: reliving reviling
# metathesis pair: renews resewn
# metathesis pair: rennet tenner
# metathesis pair: rennets tenners
# metathesis pair: repertoires repertories
# metathesis pair: repin ripen
# metathesis pair: repined ripened
# metathesis pair: repiner ripener
# metathesis pair: repiners ripeners
# metathesis pair: repining ripening
# metathesis pair: repins ripens
# metathesis pair: serries sirrees
# metathesis pair: sawer sewar
# metathesis pair: sewar swear
# metathesis pair: sawers sewars
# metathesis pair: sewars swears
# metathesis pair: reserve reverse
# metathesis pair: reveres reverse
# metathesis pair: reveres severer
# metathesis pair: reserver reverser
# metathesis pair: reservers reversers
# metathesis pair: reserves reverses
# metathesis pair: reserving reversing
# metathesis pair: resetting retesting
# metathesis pair: silverer sliverer
# metathesis pair: silverers sliverers
# metathesis pair: resins serins
# metathesis pair: serins sirens
# metathesis pair: roster sorter
# metathesis pair: rosters sorters
# metathesis pair: resow serow
# metathesis pair: resows serows
# metathesis pair: scepters sceptres
# metathesis pair: scepters specters
# metathesis pair: sceptres spectres
# metathesis pair: specters spectres
# metathesis pair: retrains terrains
# metathesis pair: retail retial
# metathesis pair: setter tester
# metathesis pair: setters testers
# metathesis pair: retired retried
# metathesis pair: retires retries
# metathesis pair: retries terries
# metathesis pair: retrain terrain
# metathesis pair: retry terry
# metathesis pair: server verser
# metathesis pair: versets verstes
# metathesis pair: rhesus rhuses
# metathesis pair: ribbon robbin
# metathesis pair: ribbons robbins
# metathesis pair: rickets tickers
# metathesis pair: ridden rinded
# metathesis pair: rilles siller
# metathesis pair: rillet tiller
# metathesis pair: rillets tillers
# metathesis pair: ringlet tingler
# metathesis pair: ringlets tinglers
# metathesis pair: tiro tori
# metathesis pair: tiro trio
# metathesis pair: tiros trios
# metathesis pair: trios trois
# metathesis pair: ripplet tippler
# metathesis pair: ripplets tipplers
# metathesis pair: rises sires
# metathesis pair: rising siring
# metathesis pair: rite tire
# metathesis pair: tier tire
# metathesis pair: rites tires
# metathesis pair: tiers tires
# metathesis pair: tires tries
# metathesis pair: rival viral
# metathesis pair: rives siver
# metathesis pair: rives vires
# metathesis pair: viers vires
# metathesis pair: roguing rouging
# metathesis pair: roost roots
# metathesis pair: roots rotos
# metathesis pair: rotos toros
# metathesis pair: toros torso
# metathesis pair: root roto
# metathesis pair: roto toro
# metathesis pair: rootlet tootler
# metathesis pair: rootlets tootlers
# metathesis pair: roser sorer
# metathesis pair: roses sores
# metathesis pair: roset rotes
# metathesis pair: rotes tores
# metathesis pair: tores torse
# metathesis pair: torses tosser
# metathesis pair: sorites sorties
# metathesis pair: rotch torch
# metathesis pair: rote tore
# metathesis pair: rotten torten
# metathesis pair: rouser sourer
# metathesis pair: rousing souring
# metathesis pair: roust routs
# metathesis pair: routs tours
# metathesis pair: torus tours
# metathesis pair: routers tourers
# metathesis pair: rout tour
# metathesis pair: router tourer
# metathesis pair: rowdier wordier
# metathesis pair: wordier worried
# metathesis pair: rowdiest wordiest
# metathesis pair: rowdily wordily
# metathesis pair: rowdiness wordiness
# metathesis pair: rowdinesses wordinesses
# metathesis pair: rowth worth
# metathesis pair: worth wroth
# metathesis pair: rowths worths
# metathesis pair: rues ruse
# metathesis pair: rues suer
# metathesis pair: ruse sure
# metathesis pair: suer sure
# metathesis pair: suer user
# metathesis pair: ruffes suffer
# metathesis pair: ruinate urinate
# metathesis pair: uranite urinate
# metathesis pair: ruinates urinates
# metathesis pair: uranites urinates
# metathesis pair: ruinating urinating
# metathesis pair: ruinous urinous
# metathesis pair: run urn
# metathesis pair: runs urns
# metathesis pair: suers users
# metathesis pair: russets tussers
# metathesis pair: rust ruts
# metathesis pair: tory troy
# metathesis pair: tory tyro
# metathesis pair: story stroy
# metathesis pair: sabers sabres
# metathesis pair: sadis saids
# metathesis pair: sae sea
# metathesis pair: sails sials
# metathesis pair: satins stains
# metathesis pair: salines silanes
# metathesis pair: salivas salvias
# metathesis pair: salons solans
# metathesis pair: salps slaps
# metathesis pair: saltiest slatiest
# metathesis pair: salty slaty
# metathesis pair: salutes taluses
# metathesis pair: salved slaved
# metathesis pair: salvers slavers
# metathesis pair: salves slaves
# metathesis pair: salves valses
# metathesis pair: salving slaving
# metathesis pair: sanity satiny
# metathesis pair: talons tolans
# metathesis pair: sat tas
# metathesis pair: satirist sitarist
# metathesis pair: satirists sitarists
# metathesis pair: saves vases
# metathesis pair: saw was
# metathesis pair: sawyer swayer
# metathesis pair: sawyers swayers
# metathesis pair: scaped spaced
# metathesis pair: scapes spaces
# metathesis pair: scaping spacing
# metathesis pair: scarpers scrapers
# metathesis pair: scarps scraps
# metathesis pair: sceptral spectral
# metathesis pair: schemer schmeer
# metathesis pair: schemers schmeers
# metathesis pair: seated teased
# metathesis pair: seeking skeeing
# metathesis pair: seeks skees
# metathesis pair: seems semes
# metathesis pair: segni sengi
# metathesis pair: sengi singe
# metathesis pair: series sirees
# metathesis pair: sends sneds
# metathesis pair: sennit tennis
# metathesis pair: sepulcher sepulchre
# metathesis pair: sepulchers sepulchres
# metathesis pair: servant versant
# metathesis pair: servants versants
# metathesis pair: serve verse
# metathesis pair: served versed
# metathesis pair: servers versers
# metathesis pair: serves verses
# metathesis pair: serving versing
# metathesis pair: servos versos
# metathesis pair: sestet testes
# metathesis pair: settee testee
# metathesis pair: settees testees
# metathesis pair: setting testing
# metathesis pair: sherds shreds
# metathesis pair: shout thous
# metathesis pair: shrieks shrikes
# metathesis pair: tushes tusseh
# metathesis pair: signing singing
# metathesis pair: signs sings
# metathesis pair: sikes skies
# metathesis pair: silly slily
# metathesis pair: silly yills
# metathesis pair: vails vials
# metathesis pair: silvering slivering
# metathesis pair: silvers slivers
# metathesis pair: sinew wines
# metathesis pair: siped spied
# metathesis pair: sipes spies
# metathesis pair: sir sri
# metathesis pair: sirs sris
# metathesis pair: sites sties
# metathesis pair: titers titres
# metathesis pair: six xis
# metathesis pair: skate stake
# metathesis pair: skated staked
# metathesis pair: skates stakes
# metathesis pair: skating staking
# metathesis pair: skeans sneaks
# metathesis pair: skeens skenes
# metathesis pair: skeets steeks
# metathesis pair: skips spiks
# metathesis pair: skirret skirter
# metathesis pair: skirrets skirters
# metathesis pair: skirt stirk
# metathesis pair: skirts stirks
# metathesis pair: sleeps speels
# metathesis pair: sleetiest steeliest
# metathesis pair: sleets steels
# metathesis pair: steels steles
# metathesis pair: sleety steely
# metathesis pair: sliming smiling
# metathesis pair: slipt spilt
# metathesis pair: spilt split
# metathesis pair: slitted stilted
# metathesis pair: slitting stilting
# metathesis pair: sloops spools
# metathesis pair: slowness snowless
# metathesis pair: smites stimes
# metathesis pair: snapless spanless
# metathesis pair: snaps spans
# metathesis pair: snatched stanched
# metathesis pair: snatchers stanchers
# metathesis pair: snatching stanching
# metathesis pair: snaws swans
# metathesis pair: sneaped speaned
# metathesis pair: sneaping speaning
# metathesis pair: sniped spined
# metathesis pair: snipes spines
# metathesis pair: snips spins
# metathesis pair: snooped spooned
# metathesis pair: snoopiest spooniest
# metathesis pair: snoopily spoonily
# metathesis pair: snooping spooning
# metathesis pair: snoops spoons
# metathesis pair: snoopy spoony
# metathesis pair: snye syne
# metathesis pair: soars soras
# metathesis pair: soldier solider
# metathesis pair: solitaires solitaries
# metathesis pair: solus souls
# metathesis pair: somberly sombrely
# metathesis pair: sonnet tonnes
# metathesis pair: sorus sours
# metathesis pair: sotols stools
# metathesis pair: sots toss
# metathesis pair: sow wos
# metathesis pair: spade spaed
# metathesis pair: speeder speered
# metathesis pair: speiled spieled
# metathesis pair: speiling spieling
# metathesis pair: speiring spiering
# metathesis pair: spirt sprit
# metathesis pair: spirt stirp
# metathesis pair: sprit strip
# metathesis pair: stirp strip
# metathesis pair: spirts sprits
# metathesis pair: spirts stirps
# metathesis pair: sprits strips
# metathesis pair: stirps strips
# metathesis pair: spite stipe
# metathesis pair: spited stiped
# metathesis pair: spites stipes
# metathesis pair: spotlight stoplight
# metathesis pair: spotlights stoplights
# metathesis pair: spouts stoups
# metathesis pair: sprats straps
# metathesis pair: spue supe
# metathesis pair: sputa stupa
# metathesis pair: staccato stoccata
# metathesis pair: staccatos stoccatas
# metathesis pair: stades tsades
# metathesis pair: stardom tsardom
# metathesis pair: stardoms tsardoms
# metathesis pair: starets staters
# metathesis pair: stars tsars
# metathesis pair: trass tsars
# metathesis pair: taste testa
# metathesis pair: teats testa
# metathesis pair: tasset tastes
# metathesis pair: staw swat
# metathesis pair: swat twas
# metathesis pair: taws twas
# metathesis pair: taws wats
# metathesis pair: wast wats
# metathesis pair: tews wets
# metathesis pair: west wets
# metathesis pair: stey stye
# metathesis pair: telos toles
# metathesis pair: storying stroying
# metathesis pair: stow swot
# metathesis pair: swot twos
# metathesis pair: tows twos
# metathesis pair: tows wots
# metathesis pair: wost wots
# metathesis pair: stows swots
# metathesis pair: strongly strongyl
# metathesis pair: worst worts
# metathesis pair: strut sturt
# metathesis pair: struts sturts
# metathesis pair: tumblers tumbrels
# metathesis pair: suable usable
# metathesis pair: suably usably
# metathesis pair: subbed subdeb
# metathesis pair: sue use
# metathesis pair: sues uses
# metathesis pair: suing using
# metathesis pair: suit tuis
# metathesis pair: thaws whats
# metathesis pair: ways yaws
# metathesis pair: weest weets
# metathesis pair: wildness windless
# metathesis pair: whist whits
# metathesis pair: tactic tictac
# metathesis pair: tactics tictacs
# metathesis pair: tailles tallies
# metathesis pair: tango tonga
# metathesis pair: tangos tongas
# metathesis pair: tantara tartana
# metathesis pair: tantaras tartanas
# metathesis pair: tardier tarried
# metathesis pair: tarries tarsier
# metathesis pair: tartlet tattler
# metathesis pair: tartlets tattlers
# metathesis pair: tav vat
# metathesis pair: tavs vats
# metathesis pair: vast vats
# metathesis pair: taw twa
# metathesis pair: taw wat
# metathesis pair: tawer water
# metathesis pair: taxes texas
# metathesis pair: teazel teazle
# metathesis pair: teazels teazles
# metathesis pair: tenias tineas
# metathesis pair: unites unties
# metathesis pair: unmiters unmitres
# metathesis pair: termor tremor
# metathesis pair: termors tremors
# metathesis pair: tew wet
# metathesis pair: tewed tweed
# metathesis pair: thaw what
# metathesis pair: theater theatre
# metathesis pair: thew whet
# metathesis pair: thews whets
# metathesis pair: thickest thickets
# metathesis pair: thickest thickset
# metathesis pair: thorned throned
# metathesis pair: tilde tiled
# metathesis pair: tilted titled
# metathesis pair: tilting titling
# metathesis pair: timber timbre
# metathesis pair: timbers timbres
# metathesis pair: tired tried
# metathesis pair: titer titre
# metathesis pair: toady today
# metathesis pair: tort trot
# metathesis pair: torts trots
# metathesis pair: tost tots
# metathesis pair: tow two
# metathesis pair: tow wot
# metathesis pair: trail trial
# metathesis pair: trails trials
# metathesis pair: triacid triadic
# metathesis pair: trying tyring
# metathesis pair: tumbler tumbrel
# metathesis pair: twist twits
# metathesis pair: unburden unburned
# metathesis pair: uncrated untraced
# metathesis pair: underdogs undergods
# metathesis pair: ungual ungula
# metathesis pair: unite untie
# metathesis pair: unleased unsealed
# metathesis pair: unlit until
# metathesis pair: unmated untamed
# metathesis pair: unserved unversed
# metathesis pair: unspilt unsplit
# metathesis pair: untilted untitled
# metathesis pair: vail vial
# metathesis pair: vailed vialed
# metathesis pair: vailing vialing
# metathesis pair: valor volar
# metathesis pair: verst verts
# metathesis pair: vest vets
# metathesis pair: veto vote
# metathesis pair: vies vise
# metathesis pair: wadder warded
# metathesis pair: wader wared
# metathesis pair: waist waits
# metathesis pair: waiver wavier
# metathesis pair: waives wavies
# metathesis pair: wake weka
# metathesis pair: weak weka
# metathesis pair: wander warden
# metathesis pair: warden warned
# metathesis pair: wanders wardens
# metathesis pair: warner warren
# metathesis pair: warners warrens
# metathesis pair: warp wrap
# metathesis pair: warps wraps
# metathesis pair: warstle wrastle
# metathesis pair: warstled wrastled
# metathesis pair: warstles wrastles
# metathesis pair: warstling wrastling
# metathesis pair: way yaw
# metathesis pair: weiner wiener
# metathesis pair: weird wried
# metathesis pair: wider wired
# metathesis pair: wired wried
# metathesis pair: weirs wries
# metathesis pair: wires wiser
# metathesis pair: wires wries
# metathesis pair: whoso woosh
# metathesis pair: wides wised
# metathesis pair: wield wiled
# metathesis pair: wilting witling
# metathesis pair: wirer wrier
# metathesis pair: wist wits
# metathesis pair: worthful wrothful
# metathesis pair: wrist writs
# metathesis pair: zaffer zaffre
# metathesis pair: zaffers zaffres

# %% [markdown]
# ### Exercise
#
# This is a bonus exercise that is not in the book.
# It is more challenging than the other exercises in this chapter, so you might want to ask a virtual assistant for help, or come back to it after you've read a few more chapters.
#
# Here's another Car Talk Puzzler
# (<http://www.cartalk.com/content/puzzlers>):
#
# > What is the longest English word, that remains a valid English word,
# > as you remove its letters one at a time?
# >
# > Now, letters can be removed from either end, or the middle, but you
# > can't rearrange any of the letters. Every time you drop a letter, you
# > wind up with another English word. If you do that, you're eventually
# > going to wind up with one letter and that too is going to be an
# > English word---one that's found in the dictionary. I want to know
# > what's the longest word and how many letters does it have?
# >
# > I'm going to give you a little modest example: Sprite. Ok? You start
# > off with sprite, you take a letter off, one from the interior of the
# > word, take the r away, and we're left with the word spite, then we
# > take the e off the end, we're left with spit, we take the s off, we're
# > left with pit, it, and I.
#
# Write a program to find all words that can be reduced in this way, and
# then find the longest one.
#
# This exercise is a little more challenging than most, so here are some
# suggestions:
#
# 1.  You might want to write a function that takes a word and computes a
#     list of all the words that can be formed by removing one letter.
#     These are the "children" of the word.
#
# 2.  Recursively, a word is reducible if any of its children are
#     reducible. As a base case, you can consider the empty string
#     reducible.
#
# 3.  The word list we've been using doesn't contain single letter
#     words. So you might have to add "I" and "a".
#
# 4.  To improve the performance of your program, you might want to
#     memoize the words that are known to be reducible.

# %%
# Solution goes here
def remove_letter(word):
    children = []
    for i in range(len(word)):
        child = word[:i] + word[i+1:]
        if child in word_list:
            children.append(child)
    return children

# %%
# Solution goes here
def is_reducible(word):
    if word == '':
        return True
    for child in remove_letter(word):
        if is_reducible(child):
            return True
    return False

# %%
# Solution goes here
word_list.append('i')
word_list.append('a')

# %%
# Solution goes here
reducible_words = []
for word in word_list:
    if is_reducible(word):
        reducible_words.append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3533279187.py in <cell line: 0>()
#       2 reducible_words = []
#       3 for word in word_list:
# ----> 4     if is_reducible(word):
#         global is_reducible = <function is_reducible at 0x7dd70c1d8f40>
#         global word = 'accelerates'
#       5         reducible_words.append(word)
#
# /tmp/ipython-input-2370896417.py in is_reducible(word='accelerates')
#       3     if word == '':
#       4         return True
# ----> 5     for child in remove_letter(word):
#         child = undefined
#         global remove_letter = <function remove_letter at 0x7dd70c1da0c0>
#         word = 'accelerates'
#       6         if is_reducible(child):
#       7             return True
#
# /tmp/ipython-input-3594892332.py in remove_letter(word='accelerates')
#       4     for i in range(len(word)):
#       5         child = word[:i] + word[i+1:]
# ----> 6         if child in word_list:
#         child = 'accelertes'
#         global word_list = ['aa', 'aah', 'aahed', 'aahing', 'aahs', 'aal', 'aalii', 'aaliis', 'aals', 'aardvark', 'aardvarks', 'aardwolf', 'aardwolves', 'aas', 'aasvogel', 'aasvogels', 'aba', 'abaca', 'abacas', 'abaci', 'aback', 'abacus', 'abacuses', 'abaft', 'abaka', 'abakas', 'abalone', 'abalones', 'abamp', 'abampere', 'abamperes', 'abamps', 'abandon', 'abandoned', 'abandoning', 'abandonment', 'abandonments', 'abandons', 'abas', 'abase', 'abased', 'abasedly', 'abasement', 'abasements', 'abaser', 'abasers', 'abases', 'abash', 'abashed', 'abashes', 'abashing', 'abasing', 'abatable', 'abate', 'abated', 'abatement', 'abatements', 'abater', 'abaters', 'abates', 'abating', 'abatis', 'abatises', 'abator', 'abators', 'abattis', 'abattises', 'abattoir', 'abattoirs', 'abaxial', 'abaxile', 'abbacies', 'abbacy', 'abbatial', 'abbe', 'abbes', 'abbess', 'abbesses', 'abbey', 'abbeys', 'abbot', 'abbotcies', 'abbotcy', 'abbots', 'abbreviate', 'abbreviated', 'abbreviates', 'abbreviating', 'abbreviation', 'abbreviations', 'abdicate', 'abdicated', 'abdicates', 'abdicating', 'abdication', 'abdications', 'abdomen', 'abdomens', 'abdomina', 'abdominal', 'abdominally', 'abduce', 'abduced', 'abducens', 'abducent', 'abducentes', 'abduces', 'abducing', 'abduct', 'abducted', 'abducting', 'abductor', 'abductores', 'abductors', 'abducts', 'abeam', 'abed', 'abele', 'abeles', 'abelmosk', 'abelmosks', 'aberrant', 'aberrants', 'aberration', 'aberrations', 'abet', 'abetment'...
#       7             children.append(child)
#       8     return children
#
# KeyboardInterrupt:

# %%
# Solution goes here

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
